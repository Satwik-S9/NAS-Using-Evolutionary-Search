# %% [markdown]
# # Project Question
#
# > Create a search function to search in a NAS space for the best performing **CNN architecture** on fashion-mnist.
#
# Your task is to create a search function which searches for the model genome string that provides the best accuracy while using the least number of parameters.
#
# Your program will return a model genome string (described below) which can be fed to a train function (provided below) to get the lowest parameter count and best accuracy after training.
#
# **This is an open research problem**. You can use any method to search for the best genome and there might not be a perfect solution possible (prefect in the sense of maximum accuracy with minimum parameters). You will likely find tradeoffs between accuracy and number of parameters and you must balance such tradeoffs at your discretion.
#
# > Aim for a search function that finds a genome with accuracy at least 75%.
#
# You are encouraged to experiment with different techniques and apply your intuition to find a good search algorithm.

# %% [markdown]
# ## CNN Architecture Constraints
#
# Your search algorithm should search for models with the following basic structure.
#
# Sequential model (no skip connections) having the following layers,
# - Any number of normal(NC) CNN layers
#   - `torch.nn.Conv2d` or `tf.keras.layers.Conv2D`
#   - A normal CNN layer has the following constraints,
#     - `stride=1`
#     - `padding=same`
#     - `1 <= kernel size < 8`
#     - Any of the following activation functions,
#       - relu
#       - sigmoid
#       - tanh
#       - swish
#       - gelu
# - **Exactly** 2 reduction(RC) CNN layers
#   - `torch.nn.Conv2d` or `tf.keras.layers.Conv2D`
#   - A reduction layer has the **same** constraints as the normal layer except the following,
#     - `stride=2`
#     - `padding=valid`
# - **Exactly** the following structure as the **final layers**,
#   - First, a Global Average Pooling 2D layer.
#     - `torch.nn.AvgPool2d(kernel_size=layer_input_image_size)` or `tf.keras.layers.GlobalAveragePooling2D`
#   - Then, a Fully Connected/Dense layer with 64 units (such that output is shape `(batch_size, 10)`)
#     - This layer can have any of the allowed activations in NC layer but all final layers must use same activation.
#     - `torch.nn.Linear(64)` or `tf.keras.layers.Dense(64)`
#   - Then, a Fully Connected/Dense layer with 10 units (such that output is shape `(batch_size, 10)`)
#     - This layer can have any of the allowed activations in NC layer but all final layers must use same activation.
#     - `torch.nn.Linear(10)` or `tf.keras.layers.Dense(10)`
#
#
# The normal(NC) and reduction(RC) layers can be in **any order** as long as the constraints above are maintained.
#
# The final layers of you model should be exactly as mentioned in these constraints.
#
# All of the above contraints **apply only to your final output**. During searching for the best architecture you can do whatever you want.
#
# Once your algorithm finds the best architecture, it should represent the architecture as a genome string (explained below) which will be fed to the training function given below to get the final accuracy.

# %%
#@title Run to setup question dependencies
# !pip install --upgrade -q tfds-nightly tensorflow-addons
# Out:
#      |████████████████████████████████| 4.0 MB 12.9 MB/s
#      |████████████████████████████████| 1.1 MB 38.4 MB/s

# %%
#@title Run to download and prepare dataset
#@markdown - https://www.tensorflow.org/datasets/catalog/fashion_mnist

import tensorflow as tf
import tensorflow_datasets as tfds

(__DS_TRAIN, __DS_TEST), __DS_INFO = tfds.load(
    'fashion_mnist',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

_ = tfds.show_examples(__DS_TEST, __DS_INFO)

# Prepare splits
def __normalize_img(image, label):
  """Normalizes images: `uint8` -> `float32`."""
  return tf.cast(image, tf.float32) / 255., label
# Prepare train split
__DS_TRAIN = __DS_TRAIN.map(__normalize_img, num_parallel_calls=tf.data.experimental.AUTOTUNE)
__DS_TRAIN = __DS_TRAIN.cache()
__DS_TRAIN = __DS_TRAIN.shuffle(__DS_INFO.splits['train'].num_examples)
__DS_TRAIN = __DS_TRAIN.batch(128)
__DS_TRAIN = __DS_TRAIN.prefetch(tf.data.experimental.AUTOTUNE)
# Prepare test split
__DS_TEST = __DS_TEST.map(__normalize_img, num_parallel_calls=tf.data.experimental.AUTOTUNE)
__DS_TEST = __DS_TEST.batch(128)
__DS_TEST = __DS_TEST.cache()
__DS_TEST = __DS_TEST.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# Downloading and preparing dataset 29.45 MiB (download: 29.45 MiB, generated: 36.42 MiB, total: 65.87 MiB) to /root/tensorflow_datasets/fashion_mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling fashion_mnist-train.tfrecord...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling fashion_mnist-test.tfrecord...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset fashion_mnist downloaded and prepared to /root/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.

# %%
#@title Run to setup model genome processing code
#@markdown A model genome is a string having `;` seperated parts where each part describes a specific layer.
#@markdown 
#@markdown For eg., this cell genome has 1 normal convolution layer followed by 2 reduction convolution layers and relu activation in the final layer.
#@markdown ```
#@markdown NC 10 2 sigmoid;RC 10 3 relu;RC 10 3 relu;FL relu;
#@markdown ```
#@markdown 
#@markdown In the above example the normal layer has 10 CNN filters having a kernel size of 2 and sigmoid activation. After the normal layer it has 2 reduction layers with 10 filters, kernel size of 3 and relu activation function. This example therefore has 3 internal layers. Finally, the genome specifies `relu` activation for the final layer(FL).
#@markdown 
#@markdown The format for each genome part for `NC` and `RC` layers is as follows,
#@markdown ```
#@markdown <NC or RC> <no. of CNN filters> <kernel size LESS THAN 8> <activation function>;
#@markdown ```
#@markdown After all `NC` and `RC` genome parts the final layer genome part has the following format,
#@markdown ```
#@markdown FL <activation function>;
#@markdown ```
#@markdown With the above, the full genome format is,
#@markdown ```
#@markdown <any number of FC/RC genome parts>;FL <activation function>;
#@markdown ```
#@markdown Here,
#@markdown - `NC` is normal genome and `RC` is reduction genome. Normal genomes keep the dimentions of the input image intact (i.e. `stride=1`), while reduction genomes make the output image dimension half of the input dimension.
#@markdown  - See the constraints section above for specific details.
#@markdown - Every genome **MUST** have **EXACTLY 2** `RC` parts. These `RC` parts can be placed anywhere in the genome.

import tensorflow as tf
import tensorflow_addons as tfa
import re
from collections import Counter

__ALLOWED_ACTIVATIONS = [
                         'relu',
                         'sigmoid',
                         'tanh',
                         'swish',
                         'gelu',
]
__VALIDATION_RE_CELL = re.compile(f'((?P<type>NC|RC) (?P<filters>\d+?) (?P<kernel>[1234567]) (?P<activation>{"|".join(__ALLOWED_ACTIVATIONS)});)+?')
__VALIDATION_RE_FL = re.compile(f'FL (?P<fl_activation>{"|".join(__ALLOWED_ACTIVATIONS)});')
__VALIDATION_RE = re.compile(f'((?P<type>NC|RC) (?P<filters>\d+?) (?P<kernel>[1234567]) (?P<activation>{"|".join(__ALLOWED_ACTIVATIONS)});)+?FL (?P<fl_activation>{"|".join(__ALLOWED_ACTIVATIONS)});')

__SAMPLE_GENOME = 'NC 1 1 sigmoid;RC 2 3 relu;RC 5 7 relu;'

def parse_genome(cellgenome: str):
  if __VALIDATION_RE.fullmatch(cellgenome) is None:
    raise Exception(f'Invalid genome (parse error): {cellgenome}\n Please check that the genome is in the correct format.')
  parse = __VALIDATION_RE_CELL.findall(cellgenome)
  # check constraints
  type_count = Counter()
  for idx, cell in enumerate(parse):
    type_count.update([cell[1]])
    filter = int(cell[2])
    kernel = int(cell[3])
    if filter < 1:
      raise Exception(f'Invalid filter size {filter} for layer {idx+1}.')
    if kernel < 1 or kernel > 7:
      raise Exception(f'Invalid kernel size {filter} for layer {idx+1}.')
  if type_count['RC'] != 2:
    raise Exception(f'Genome must have exacly 2 RC parts. Your genome has {type_count["RC"]} RC parts.')
  return parse + __VALIDATION_RE_FL.findall(cellgenome)

def genome_to_model(cellgenome: str, lr: float = 2e-3, lr_decay: float = 0.05):
  # parse genome
  parsed = parse_genome(cellgenome)
  def _match_to_layer(match_tuple, idx):
    return tf.keras.layers.Conv2D(
        filters = int(match_tuple[2]),
        kernel_size = int(match_tuple[3]),
        strides = 1 if match_tuple[1] == 'NC' else 2,
        name = f'Layer_{idx}_{match_tuple[1]}',
        activation = match_tuple[4],
        padding = 'same' if match_tuple[1] == 'NC' else 'valid',
    )
  # create model object
  model = tf.keras.Sequential(
    [
      *[_match_to_layer(cell, idx) for idx, cell in enumerate(parsed[:-1])],
      tf.keras.layers.GlobalAveragePooling2D(),
      tf.keras.layers.Dense(
          64,
          activation=parsed[-1],
      ),
      tf.keras.layers.Dense(
          __DS_INFO.features['label'].num_classes,
          activation=parsed[-1],
      ),
    ]
  )
  # compile the model
  model.compile(
      optimizer=tfa.optimizers.AdamW(
          learning_rate=tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=lr,
            decay_steps=len(__DS_TRAIN)*10,
            decay_rate=lr_decay,
          ),
          weight_decay=1e-9,
      ),
      loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
      metrics=['accuracy']
  )
  model.build((None, *__DS_INFO.features['image'].shape))
  return model

# %%
#@title Use this form to validate a genome and see the resulting model
#@markdown Enter your genome in this text field and then run this cell.
__fr_model_genome = "NC 256 5 tanh;RC 64 5 relu;NC 256 5 tanh;NC 4 3 tanh;RC 16 3 tanh;FL relu;" #@param {type:"string"}

try:
  __fr_model = genome_to_model(__fr_model_genome)
  __fr_model.summary()
  del __fr_model
except Exception as e:
  print(e)
  print()
  print(f'Your input genome: {__fr_model_genome}')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 256)       6656
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 64)        409664
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       409856
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 4)         9220
#
#  Layer_4_RC (Conv2D)         (None, 5, 5, 16)          592
#
#  global_average_pooling2d (G  (None, 16)               0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                1088
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 837,726
# Trainable params: 837,726
# Non-trainable params: 0
# _________________________________________________________________

# %%
#@title Run to setup model training code
#@markdown You are provided with two functions,
#@markdown - **`get_model_parameters(model_genome: str)`**: This function accepts the model genome string and returns the number of parameters that the model will have. You can use this function to query for the number of parameters without training the model entirely.
#@markdown 
#@markdown    **Returns**: A single integer representing the number of parameters in the model.

#@markdown - **`train_model(model_genome: str, verbose: int = 1, lr: float = None, lr_decacy: float = None)`**: This function accepts the model genome string and trains the model on the Fashion-MNIST dataset. You must use this function to train models based on your genome string.
#@markdown 
#@markdown      - If `verbose` is `0` then this function does not print anything while training
#@markdown      - If `verbose` is `1` then it prints the training progess on each call and the final test accuracy.
#@markdown      - If `verbose` is `2` then it prints everything from `varbose=1` and also prints the model summary (structure).
#@markdown 
#@markdown  It accepts a learning rate (`lr`) and a learning rate exponential decay rate (`lr_decay`). You do not need to provide values for `lr` and `lr_decay`, the default values are tuned to give good performance  3~10 layer networks. Below you will find some example values for a sample shallow network and a sample deep network.
#@markdown 
#@markdown   **Returns**: A tuple of `(test accuracy, train accuracy, number of parameters)`.
#@markdown 
#@markdown Using the above two functions you must create a search method to search for a model genome which gives the maximum **test accuracy**. You are given the train accuracy to identify _overfitting_ if you wish to do so. You can also use the number of parameters to prefer models having fewer parameters and find a good balance between test accuracy and number of parameters.

def get_model_parameters(modelgenome: str):
  '''
  Returns the number of parameters that this genome creates.
  '''
  model = genome_to_model(modelgenome)
  return model.count_params()

def train_model(modelgenome: str, verbose: int = 1, lr: float = None, lr_decay: float = None):
  '''
  Accepts a genome string and trains the corresponding model on Fashion MNIST dataset.
  Thorws exceptions if the provided genome is invalid.
  Returns a tuple: (test accuracy, train accuracy, number of parameters)
  '''
  model = genome_to_model(modelgenome, lr=lr, lr_decay=lr_decay)
  n_params = model.count_params()
  if verbose > 0:
    print(f'Training genome: {modelgenome}')
    print(f'Model params: {n_params}')
  if verbose > 1:
    model.summary()
  # train model
  callbacks = [
    tf.keras.callbacks.EarlyStopping(
      monitor='val_loss',
      mode='min',
      baseline=10.0,
      patience=2,
      min_delta=0.005,
      verbose=verbose,
    )
  ]
  if verbose > 0:
    callbacks.append(
      tfa.callbacks.TQDMProgressBar(
        update_per_second = 1,
        leave_epoch_progress = verbose > 1,
        leave_overall_progress = verbose > 1,
      )
    )
  ret = model.fit(
      __DS_TRAIN,
      epochs=10,
      verbose=0,
      callbacks=callbacks,
      validation_data=__DS_TEST,
  )
  # delete model
  del model
  # get best history
  best_idx = max(range(len(ret.history['val_accuracy'])), key=ret.history['val_accuracy'].__getitem__)
  best_history = {
      k: v[best_idx] for k, v in ret.history.items()
  }
  if verbose > 0:
    print(f'Best test accuracy: {best_history["val_accuracy"]}')
  return (best_history['val_accuracy'], best_history['accuracy'], n_params)

# %%
#@title Use this form to train specific genomes
#@markdown Enter your genome in this text field and then run this cell.
#@markdown 
__fr_model_genome = "NC 256 5 tanh;RC 64 5 relu;NC 4 3 tanh;RC 16 3 tanh;FL relu;" #@param {type:"string"}

#@markdown You can finetune training hyperparameters here, (given values are good defaults and you shouldn't have to change for good results)
__fr_lr = 1e-3 #@param {type:"number"}
__fr_lr_decay = 0.1 #@param {type:"number"}

try:
  # Train
  print('Return value:', train_model(__fr_model_genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay))
except Exception as e:
  print(e)
  print()
  print(f'Your input genome: {__fr_model_genome}')
# Out:
# Training genome: NC 256 5 tanh;RC 64 5 relu;NC 4 3 tanh;RC 16 3 tanh;FL relu;
# Model params: 420958
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 256)       6656
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 64)        409664
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 4)         2308
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 16)          592
#
#  global_average_pooling2d_1   (None, 16)               0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 64)                1088
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 420,958
# Trainable params: 420,958
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0187s vs `on_train_batch_end` time: 0.0222s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0187s vs `on_train_batch_end` time: 0.0222s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.8259999752044678
# Return value: (0.8259999752044678, 0.8392999768257141, 420958)

# %%
#@title Deep model genome example
#@markdown Enter your genome in this text field and then run this cell.
#@markdown 
__fr_model_genome = "NC 32 5 relu;RC 32 5 relu;RC 64 6 relu;NC 64 5 relu;NC 16 4 relu;FL relu;" #@param {type:"string"}

#@markdown You can finetune training hyperparameters here, (given values are good defaults and you shouldn't have to change for good results)
__fr_lr = 1e-3 #@param {type:"number"}
__fr_lr_decay = 0.1 #@param {type:"number"}

try:
  # Train
  print('Return value:', train_model(__fr_model_genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay))
except Exception as e:
  print(e)
  print()
  print(f'Your input genome: {__fr_model_genome}')
# Out:
# Training genome: NC 32 5 relu;RC 32 5 relu;RC 64 6 relu;NC 64 5 relu;NC 16 4 relu;FL relu;
# Model params: 220858
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 32)        832
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 32)        25632
#
#  Layer_2_RC (Conv2D)         (None, 4, 4, 64)          73792
#
#  Layer_3_NC (Conv2D)         (None, 4, 4, 64)          102464
#
#  Layer_4_NC (Conv2D)         (None, 4, 4, 16)          16400
#
#  global_average_pooling2d_2   (None, 16)               0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 64)                1088
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 220,858
# Trainable params: 220,858
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1935b3aba83a> in <module>()
#      10 try:
#      11   # Train
# ---> 12   print('Return value:', train_model(__fr_model_genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay))
#      13 except Exception as e:
#      14   print(e)
#
# <ipython-input-7-addba1ae32ec> in train_model(modelgenome, verbose, lr, lr_decay)
#      61       verbose=0,
#      62       callbacks=callbacks,
# ---> 63       validation_data=__DS_TEST,
#      64   )
#      65   # delete model
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
# -> 3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#    3133   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958       # No tape is watching; skip to running the function.
#    1959       return self._build_call_outputs(self._inference_function.call(
# -> 1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#    1962         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     601               inputs=args,
#     602               attrs=attrs,
# --> 603               ctx=ctx)
#     604         else:
#     605           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Hints
#
# - Consider caching genome results for faster querying.
#   - This has a risk. The training process itself is non-deterministic and thus training the same genome multiple times can sometimes give drastically different results. Generally such difference in accuracy of the same genome is small but sometimes it be upto 30%.
# - Consider saving your search algorithm state such that it can resume from a previous search point if it gets interrupted due to a crash or colab time restrictions.
#   - Google colab is free and hence it has time limits on how long you can use the GPU. If you implement checkpointing in your code such that it saves checkpoints on your GDrive, you can save a lot of time when such interruptions happen.
#   - You can mount your GDrive to colab and save/load files from your drive folders.
# - Don't forget to enable GPU in colab.
#   - https://colab.research.google.com/notebooks/gpu.ipynb
# - If colab shows errors in code that was working before try to do `Runtime->Restart Runtime`. This is especially true if you stopped execution while a model was being trained.
#   - You can also try `Runtime->Factory Reset Runtime` to get a clean slate (revert installed libraries to colab defaults).

# %% [markdown]
# # Answer
# Write your answer and its code under this section.

# %%
function = ["NC","RC"]
filters = ["1","2","4","8","16","32","64","128","256"]
kernels = ["1","2","3","4","5","6","7"]
af = ["relu","sigmoid","tanh"]
nc_layers = []
rc_layers =[]
for i in range(len(function)):
  for j in range(len(filters)):
    for k in range(len(kernels)):
      for l in range(len(af)):
        str = function[i]+" "+filters[j]+" "+kernels[k]+" "+af[l]
        if function[i]=='NC':
          nc_layers.append(str)
        else:
          rc_layers.append(str)
print(nc_layers) 
print(rc_layers)
# Out:
# ['NC 1 1 relu', 'NC 1 1 sigmoid', 'NC 1 1 tanh', 'NC 1 2 relu', 'NC 1 2 sigmoid', 'NC 1 2 tanh', 'NC 1 3 relu', 'NC 1 3 sigmoid', 'NC 1 3 tanh', 'NC 1 4 relu', 'NC 1 4 sigmoid', 'NC 1 4 tanh', 'NC 1 5 relu', 'NC 1 5 sigmoid', 'NC 1 5 tanh', 'NC 1 6 relu', 'NC 1 6 sigmoid', 'NC 1 6 tanh', 'NC 1 7 relu', 'NC 1 7 sigmoid', 'NC 1 7 tanh', 'NC 2 1 relu', 'NC 2 1 sigmoid', 'NC 2 1 tanh', 'NC 2 2 relu', 'NC 2 2 sigmoid', 'NC 2 2 tanh', 'NC 2 3 relu', 'NC 2 3 sigmoid', 'NC 2 3 tanh', 'NC 2 4 relu', 'NC 2 4 sigmoid', 'NC 2 4 tanh', 'NC 2 5 relu', 'NC 2 5 sigmoid', 'NC 2 5 tanh', 'NC 2 6 relu', 'NC 2 6 sigmoid', 'NC 2 6 tanh', 'NC 2 7 relu', 'NC 2 7 sigmoid', 'NC 2 7 tanh', 'NC 4 1 relu', 'NC 4 1 sigmoid', 'NC 4 1 tanh', 'NC 4 2 relu', 'NC 4 2 sigmoid', 'NC 4 2 tanh', 'NC 4 3 relu', 'NC 4 3 sigmoid', 'NC 4 3 tanh', 'NC 4 4 relu', 'NC 4 4 sigmoid', 'NC 4 4 tanh', 'NC 4 5 relu', 'NC 4 5 sigmoid', 'NC 4 5 tanh', 'NC 4 6 relu', 'NC 4 6 sigmoid', 'NC 4 6 tanh', 'NC 4 7 relu', 'NC 4 7 sigmoid', 'NC 4 7 tanh', 'NC 8 1 relu', 'NC 8 1 sigmoid', 'NC 8 1 tanh', 'NC 8 2 relu', 'NC 8 2 sigmoid', 'NC 8 2 tanh', 'NC 8 3 relu', 'NC 8 3 sigmoid', 'NC 8 3 tanh', 'NC 8 4 relu', 'NC 8 4 sigmoid', 'NC 8 4 tanh', 'NC 8 5 relu', 'NC 8 5 sigmoid', 'NC 8 5 tanh', 'NC 8 6 relu', 'NC 8 6 sigmoid', 'NC 8 6 tanh', 'NC 8 7 relu', 'NC 8 7 sigmoid', 'NC 8 7 tanh', 'NC 16 1 relu', 'NC 16 1 sigmoid', 'NC 16 1 tanh', 'NC 16 2 relu', 'NC 16 2 sigmoid', 'NC 16 2 tanh', 'NC 16 3 relu', 'NC 16 3 sigmoid', 'NC 16 3 tanh', 'NC 16 4 relu', 'NC 16 4 sigmoid', 'NC 16 4 tanh', 'NC 16 5 relu', 'NC 16 5 sigmoid', 'NC 16 5 tanh', 'NC 16 6 relu', 'NC 16 6 sigmoid', 'NC 16 6 tanh', 'NC 16 7 relu', 'NC 16 7 sigmoid', 'NC 16 7 tanh', 'NC 32 1 relu', 'NC 32 1 sigmoid', 'NC 32 1 tanh', 'NC 32 2 relu', 'NC 32 2 sigmoid', 'NC 32 2 tanh', 'NC 32 3 relu', 'NC 32 3 sigmoid', 'NC 32 3 tanh', 'NC 32 4 relu', 'NC 32 4 sigmoid', 'NC 32 4 tanh', 'NC 32 5 relu', 'NC 32 5 sigmoid', 'NC 32 5 tanh', 'NC 32 6 relu', 'NC 32 6 sigmoid', 'NC 32 6 tanh', 'NC 32 7 relu', 'NC 32 7 sigmoid', 'NC 32 7 tanh', 'NC 64 1 relu', 'NC 64 1 sigmoid', 'NC 64 1 tanh', 'NC 64 2 relu', 'NC 64 2 sigmoid', 'NC 64 2 tanh', 'NC 64 3 relu', 'NC 64 3 sigmoid', 'NC 64 3 tanh', 'NC 64 4 relu', 'NC 64 4 sigmoid', 'NC 64 4 tanh', 'NC 64 5 relu', 'NC 64 5 sigmoid', 'NC 64 5 tanh', 'NC 64 6 relu', 'NC 64 6 sigmoid', 'NC 64 6 tanh', 'NC 64 7 relu', 'NC 64 7 sigmoid', 'NC 64 7 tanh', 'NC 128 1 relu', 'NC 128 1 sigmoid', 'NC 128 1 tanh', 'NC 128 2 relu', 'NC 128 2 sigmoid', 'NC 128 2 tanh', 'NC 128 3 relu', 'NC 128 3 sigmoid', 'NC 128 3 tanh', 'NC 128 4 relu', 'NC 128 4 sigmoid', 'NC 128 4 tanh', 'NC 128 5 relu', 'NC 128 5 sigmoid', 'NC 128 5 tanh', 'NC 128 6 relu', 'NC 128 6 sigmoid', 'NC 128 6 tanh', 'NC 128 7 relu', 'NC 128 7 sigmoid', 'NC 128 7 tanh', 'NC 256 1 relu', 'NC 256 1 sigmoid', 'NC 256 1 tanh', 'NC 256 2 relu', 'NC 256 2 sigmoid', 'NC 256 2 tanh', 'NC 256 3 relu', 'NC 256 3 sigmoid', 'NC 256 3 tanh', 'NC 256 4 relu', 'NC 256 4 sigmoid', 'NC 256 4 tanh', 'NC 256 5 relu', 'NC 256 5 sigmoid', 'NC 256 5 tanh', 'NC 256 6 relu', 'NC 256 6 sigmoid', 'NC 256 6 tanh', 'NC 256 7 relu', 'NC 256 7 sigmoid', 'NC 256 7 tanh']
# ['RC 1 1 relu', 'RC 1 1 sigmoid', 'RC 1 1 tanh', 'RC 1 2 relu', 'RC 1 2 sigmoid', 'RC 1 2 tanh', 'RC 1 3 relu', 'RC 1 3 sigmoid', 'RC 1 3 tanh', 'RC 1 4 relu', 'RC 1 4 sigmoid', 'RC 1 4 tanh', 'RC 1 5 relu', 'RC 1 5 sigmoid', 'RC 1 5 tanh', 'RC 1 6 relu', 'RC 1 6 sigmoid', 'RC 1 6 tanh', 'RC 1 7 relu', 'RC 1 7 sigmoid', 'RC 1 7 tanh', 'RC 2 1 relu', 'RC 2 1 sigmoid', 'RC 2 1 tanh', 'RC 2 2 relu', 'RC 2 2 sigmoid', 'RC 2 2 tanh', 'RC 2 3 relu', 'RC 2 3 sigmoid', 'RC 2 3 tanh', 'RC 2 4 relu', 'RC 2 4 sigmoid', 'RC 2 4 tanh', 'RC 2 5 relu', 'RC 2 5 sigmoid', 'RC 2 5 tanh', 'RC 2 6 relu', 'RC 2 6 sigmoid', 'RC 2 6 tanh', 'RC 2 7 relu', 'RC 2 7 sigmoid', 'RC 2 7 tanh', 'RC 4 1 relu', 'RC 4 1 sigmoid', 'RC 4 1 tanh', 'RC 4 2 relu', 'RC 4 2 sigmoid', 'RC 4 2 tanh', 'RC 4 3 relu', 'RC 4 3 sigmoid', 'RC 4 3 tanh', 'RC 4 4 relu', 'RC 4 4 sigmoid', 'RC 4 4 tanh', 'RC 4 5 relu', 'RC 4 5 sigmoid', 'RC 4 5 tanh', 'RC 4 6 relu', 'RC 4 6 sigmoid', 'RC 4 6 tanh', 'RC 4 7 relu', 'RC 4 7 sigmoid', 'RC 4 7 tanh', 'RC 8 1 relu', 'RC 8 1 sigmoid', 'RC 8 1 tanh', 'RC 8 2 relu', 'RC 8 2 sigmoid', 'RC 8 2 tanh', 'RC 8 3 relu', 'RC 8 3 sigmoid', 'RC 8 3 tanh', 'RC 8 4 relu', 'RC 8 4 sigmoid', 'RC 8 4 tanh', 'RC 8 5 relu', 'RC 8 5 sigmoid', 'RC 8 5 tanh', 'RC 8 6 relu', 'RC 8 6 sigmoid', 'RC 8 6 tanh', 'RC 8 7 relu', 'RC 8 7 sigmoid', 'RC 8 7 tanh', 'RC 16 1 relu', 'RC 16 1 sigmoid', 'RC 16 1 tanh', 'RC 16 2 relu', 'RC 16 2 sigmoid', 'RC 16 2 tanh', 'RC 16 3 relu', 'RC 16 3 sigmoid', 'RC 16 3 tanh', 'RC 16 4 relu', 'RC 16 4 sigmoid', 'RC 16 4 tanh', 'RC 16 5 relu', 'RC 16 5 sigmoid', 'RC 16 5 tanh', 'RC 16 6 relu', 'RC 16 6 sigmoid', 'RC 16 6 tanh', 'RC 16 7 relu', 'RC 16 7 sigmoid', 'RC 16 7 tanh', 'RC 32 1 relu', 'RC 32 1 sigmoid', 'RC 32 1 tanh', 'RC 32 2 relu', 'RC 32 2 sigmoid', 'RC 32 2 tanh', 'RC 32 3 relu', 'RC 32 3 sigmoid', 'RC 32 3 tanh', 'RC 32 4 relu', 'RC 32 4 sigmoid', 'RC 32 4 tanh', 'RC 32 5 relu', 'RC 32 5 sigmoid', 'RC 32 5 tanh', 'RC 32 6 relu', 'RC 32 6 sigmoid', 'RC 32 6 tanh', 'RC 32 7 relu', 'RC 32 7 sigmoid', 'RC 32 7 tanh', 'RC 64 1 relu', 'RC 64 1 sigmoid', 'RC 64 1 tanh', 'RC 64 2 relu', 'RC 64 2 sigmoid', 'RC 64 2 tanh', 'RC 64 3 relu', 'RC 64 3 sigmoid', 'RC 64 3 tanh', 'RC 64 4 relu', 'RC 64 4 sigmoid', 'RC 64 4 tanh', 'RC 64 5 relu', 'RC 64 5 sigmoid', 'RC 64 5 tanh', 'RC 64 6 relu', 'RC 64 6 sigmoid', 'RC 64 6 tanh', 'RC 64 7 relu', 'RC 64 7 sigmoid', 'RC 64 7 tanh', 'RC 128 1 relu', 'RC 128 1 sigmoid', 'RC 128 1 tanh', 'RC 128 2 relu', 'RC 128 2 sigmoid', 'RC 128 2 tanh', 'RC 128 3 relu', 'RC 128 3 sigmoid', 'RC 128 3 tanh', 'RC 128 4 relu', 'RC 128 4 sigmoid', 'RC 128 4 tanh', 'RC 128 5 relu', 'RC 128 5 sigmoid', 'RC 128 5 tanh', 'RC 128 6 relu', 'RC 128 6 sigmoid', 'RC 128 6 tanh', 'RC 128 7 relu', 'RC 128 7 sigmoid', 'RC 128 7 tanh', 'RC 256 1 relu', 'RC 256 1 sigmoid', 'RC 256 1 tanh', 'RC 256 2 relu', 'RC 256 2 sigmoid', 'RC 256 2 tanh', 'RC 256 3 relu', 'RC 256 3 sigmoid', 'RC 256 3 tanh', 'RC 256 4 relu', 'RC 256 4 sigmoid', 'RC 256 4 tanh', 'RC 256 5 relu', 'RC 256 5 sigmoid', 'RC 256 5 tanh', 'RC 256 6 relu', 'RC 256 6 sigmoid', 'RC 256 6 tanh', 'RC 256 7 relu', 'RC 256 7 sigmoid', 'RC 256 7 tanh']

# %%
'''
from random import randint
accuracy = []
states = []
genome = nc_layers[0]+";"+rc_layers[0]+";"+rc_layers[1]+";"+"FL relu;"
r= train_model(genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay)
print(r)
accuracy.append([genome,r[0]*100])
while r[0]*100<75 :
  a = randint(0,len(nc_layers)-1)
  b = randint(0,len(rc_layers)-1)
  c = randint(0,len(rc_layers)-1)
  if r[0]>0.75 and r[0]<0.85:
    genome = nc_layers[a]+";"+nc_layers[b]+";"+rc_layers[b]+";"+rc_layers[c]+";"+"FL relu;"
  else:
    genome = nc_layers[a]+";"+rc_layers[b]+";"+rc_layers[c]+";"+"FL relu;"
  r= train_model(genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay)
  print(r)
  accuracy.append([genome,r[0]*100])
'''
# Out:
# '\nfrom random import randint\naccuracy = []\nstates = []\ngenome = nc_layers[0]+";"+rc_layers[0]+";"+rc_layers[1]+";"+"FL relu;"\nr= train_model(genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay)\nprint(r)\naccuracy.append([genome,r[0]*100])\nwhile r[0]*100<75 :\n  a = randint(0,len(nc_layers)-1)\n  b = randint(0,len(rc_layers)-1)\n  c = randint(0,len(rc_layers)-1)\n  if r[0]>0.75 and r[0]<0.85:\n    genome = nc_layers[a]+";"+nc_layers[b]+";"+rc_layers[b]+";"+rc_layers[c]+";"+"FL relu;"\n  else:\n    genome = nc_layers[a]+";"+rc_layers[b]+";"+rc_layers[c]+";"+"FL relu;"\n  r= train_model(genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay)\n  print(r)\n  accuracy.append([genome,r[0]*100])\n'

# %%
'''
for i in range(len(accuracy)):
  print(accuracy[i])
'''
# Out:
# '\nfor i in range(len(accuracy)):\n  print(accuracy[i])\n'

# %%
# importing library
import random
# defining the function that generates a random layer from defined filters, functions and kernels
def random_layer(f,l,k,af,layertype):
  while True:
    a = random.randint(0,len(f)-1)
    b = random.randint(0,len(l)-1)
    c = random.randint(0,len(k)-1)
    d = random.randint(0,len(af)-1)
    string = f[a]+" "+l[b]+" "+k[c]+" "+af[d]+";"
    #print(string,string[:2])
    if string[:2]==layertype:
      return string

# defining the function that generates a random architecture with given number of layers
def random_architecture(k):
  s = []
  a = ''
  for i in range(k-2-1):
    s.append(random_layer(function,filters,kernels,af,"NC"))
  for i in range(2):
    s.append(random_layer(function,filters,kernels,af,"RC"))
  random.shuffle(s)
  s.append("FL relu;")
  for i in range(len(s)):
    a = a + s[i]
  return a


#arch = random_architecture(6)
#print(arch)

# %%
# mutation class containg four different types of mutations.
class Mutation():

  def swap_mutation(self,model_genome):
    """
    Randomly choose two layers in the model genome and swap them
    """
    # creating list and its copies
    la = []
    la = model_genome.split(';')
    fl = "FL relu"
    la.remove("FL relu")
    la_copy = la[:]  
    # print(f"{la}\n{la_copy}")

    # choosing two indices at random
    choice1 = random.choice(la_copy)
    ### print(choice1)
    la_copy.remove(choice1)
    choice2 = random.choice(la_copy)

    index1, index2 = la.index(choice1), la.index(choice2)
    # swapping two layers in the genome
    la[index1], la[index2] = choice2, choice1  
    print(f"Swapping :\n{choice1}\n{choice2}")
    # print(la)
    
    swapped_genome = ";".join(la) + fl + ";"
    # print(swapped_genome)

    return swapped_genome

  def inversion_mutation(self,model_genome):
    """
    Select a sequence of layers at random and invert them
    """
    la = []
    la = model_genome.split(';')
    fl = "FL relu"
    la.remove("FL relu")
    # main_str = ";".join(la)

    idx1 = random.randint(0, len(la)-2)
    idx2 = random.randint(idx1+1, len(la)-1)
    # substr = get_substring(main_str, substr_len)
    sa = la[idx1:idx2]
    print(f"{la}\n{fl}\n{idx1}\n{idx2}\n{sa}")
    
    sa = sa[::-1]
    la[idx1:idx2] = sa

    inverted_genome = ";".join(la) + fl + ";"

    return inverted_genome

  def add_layer_mutation(self,model_genome):
    """
    choose a layers in the model genome and replace them by new layer
    """
    layer1 = []
    layer2 = random_layer(function,filters,kernels,af,"NC")
    layer2 = layer2.split(";")
    print(layer2)
    layer1 = model_genome.split(';') 
    genome = ''
    for i in range(len(layer1)-3):
      if layer1[i][:2] == "NC":
        layer1[i]=layer2[0]
        break
    for i in range(len(layer1)-1):
      genome+=layer1[i]+";"
    print(layer1)
    print(layer2)
    print(genome)
    return genome 
  
  def filter_mutation(self,model_genome):
    """
    Choose a layer in the model genome and change the number of filters in them
    """
    layer1 = model_genome.split(';')
    layer3 = []
    genome = ''
    for i in range(len(layer1)):
      if layer1[i][:2]=="NC":
        s = ''
        b = random.randint(0,len(filters)-1)
        layer2 = layer1[i].split(" ")
        if layer2[1]==filters[b]:
          b = random.randint(0,len(filters)-1)
        layer2[1]=filters[b]
        print(layer2[1])
        for j in range(len(layer2)):
          if j != len(layer2)-1:
            s = s + layer2[j]+" "
          else:
            s = s + layer2[j]
        print(s)
        layer3.append(s)
      else:
        layer3.append(layer1[i])
    for i in range(len(layer3)-1):
      genome+=layer3[i]+";"
    print(layer3)
    return genome
    
# an example of mutations
g = 'NC 256 5 tanh;RC 64 5 relu;NC 256 5 tanh;NC 4 3 tanh;RC 16 3 tanh;FL relu;'
m = mutation()
print(m.swap_mutation(g),'\n')
print(m.inversion_mutation(g),'\n')
print(m.add_layer_mutation(g),'\n')
print(m.filter_mutation(g),'\n')
# Out:
# Swapping :
# NC 256 5 tanh
# RC 64 5 relu
# RC 64 5 relu;NC 256 5 tanh;NC 256 5 tanh;NC 4 3 tanh;RC 16 3 tanh;FL relu;
#
# ['NC 256 5 tanh', 'RC 64 5 relu', 'NC 256 5 tanh', 'NC 4 3 tanh', 'RC 16 3 tanh', '']
# FL relu
# 4
# 5
# ['RC 16 3 tanh']
# NC 256 5 tanh;RC 64 5 relu;NC 256 5 tanh;NC 4 3 tanh;RC 16 3 tanh;FL relu;
#
# ['NC 8 6 relu', '']
# ['NC 8 6 relu', 'RC 64 5 relu', 'NC 256 5 tanh', 'NC 4 3 tanh', 'RC 16 3 tanh', 'FL relu', '']
# ['NC 8 6 relu', '']
# NC 8 6 relu;RC 64 5 relu;NC 256 5 tanh;NC 4 3 tanh;RC 16 3 tanh;FL relu;
# NC 8 6 relu;RC 64 5 relu;NC 256 5 tanh;NC 4 3 tanh;RC 16 3 tanh;FL relu;
#
# 4
# NC 4 5 tanh
# 8
# NC 8 5 tanh
# 128
# NC 128 3 tanh
# ['NC 4 5 tanh', 'RC 64 5 relu', 'NC 8 5 tanh', 'NC 128 3 tanh', 'RC 16 3 tanh', 'FL relu', '']
# NC 4 5 tanh;RC 64 5 relu;NC 8 5 tanh;NC 128 3 tanh;RC 16 3 tanh;FL relu;

# %%
# defining the class of algorithm
class Evolutionary_algorithm():

  def __init__(self,p,layers):
    self.p = p
    self.layers = layers
    self.population = []
    self.history = []
    self.accuracy = []

  # initialize population
  def initialise(self):
    for i in range(self.p):
      x = random_architecture(self.layers)
      if x not in self.population:
        r = train_model(x, verbose=2, lr=1e-3, lr_decay=0.1)
        self.population.append(x)
        self.history.append(x)
        self.accuracy.append(r)
    return self.population,self.accuracy,self.history

  def search(self,nsamples, mutation:str = 'filter'):
    # running initial algorithm
    while True:
      samples = []
      for i in range(nsamples):
        a = random.randint(0,len(self.population)-1)
        if self.population[a] not in samples:
          samples.append([self.population[a],self.accuracy[a]])
      max1,max2 = 0,0
      j,k = 0,0
      for i in range(len(samples)):
        if samples[i][1][0]>max1:
          max2 = max1
          max1 = samples[i][1][0]
          k = j
          j = i
      print("Architecture having Highest accuracy in samples:\n",samples[j])
      print("Architecture having Second highest accuracy in samples:\n",samples[k])
      if max1>0.75:
        return samples[j],self.population,self.accuracy,self.history
      
      # mutating the genome
      m = Mutation()
      if mutation == 'filter':
        new_ge = m.filter_mutation(samples[j][0])
      elif mutation == 'swap':
        new_ge = m.swap_mutation(samples[j][0])
      elif mutation == 'inversion':
        new_ge = m.inversion_mutation(samples[j][0])
      elif mutation == 'addl':
        new_ge = m.add_layer_mutation(samples[j][0])
      print(new_ge)

      # training model on the mutated genome
      if new_ge not in self.population and mutation != 'swap':
        r = train_model(new_ge, verbose=2, lr=1e-3, lr_decay=0.1)
        if r[0]-samples[j][1][0]>0:
          print("Mutation accuracy is greater than parent adding child to population")
          self.population.append(new_ge)
          self.history.append(new_ge)
          self.accuracy.append(r)
        elif new_ge not in self.population and mutation != 'swap':
          try:
            r = train_model(new_ge, verbose=2, lr=1e-3, lr_decay=0.1)
          except Exception as e:
            continue
          if r[0]-samples[j][1][0]>0:
            print("Mutation accuracy is greater than parent adding child to population")
            self.population.append(new_ge)
            self.history.append(new_ge)
            self.accuracy.append(r)
        else:
          print("Mutation accuracy is less than parent not adding child to population")

# %%
model = Evolutionary_algorithm(6,6)
pop , acc, hist = model.initialise()
print(pop)
print(acc)
# Out:
# Training genome: NC 2 6 relu;RC 4 7 tanh;RC 32 1 tanh;NC 128 7 tanh;NC 4 2 sigmoid;FL relu;
# Model params: 204484
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 2)         74
#
#  Layer_1_RC (Conv2D)         (None, 11, 11, 4)         396
#
#  Layer_2_RC (Conv2D)         (None, 6, 6, 32)          160
#
#  Layer_3_NC (Conv2D)         (None, 6, 6, 128)         200832
#
#  Layer_4_NC (Conv2D)         (None, 6, 6, 4)           2052
#
#  global_average_pooling2d_29  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_58 (Dense)            (None, 64)                320
#
#  dense_59 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 204,484
# Trainable params: 204,484
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.4781000018119812
# Training genome: NC 128 5 sigmoid;RC 256 5 relu;NC 4 4 relu;NC 64 7 relu;RC 4 5 sigmoid;FL relu;
# Model params: 859154
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       3328
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 256)       819456
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 4)         16388
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 64)        12608
#
#  Layer_4_RC (Conv2D)         (None, 4, 4, 4)           6404
#
#  global_average_pooling2d_30  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_60 (Dense)            (None, 64)                320
#
#  dense_61 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 859,154
# Trainable params: 859,154
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0222s vs `on_train_batch_end` time: 0.0351s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0222s vs `on_train_batch_end` time: 0.0351s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Training genome: RC 8 6 sigmoid;NC 16 3 sigmoid;NC 64 1 tanh;RC 4 1 relu;NC 128 2 tanh;FL relu;
# Model params: 13894
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 12, 12, 8)         296
#
#  Layer_1_NC (Conv2D)         (None, 12, 12, 16)        1168
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 64)        1088
#
#  Layer_3_RC (Conv2D)         (None, 6, 6, 4)           260
#
#  Layer_4_NC (Conv2D)         (None, 6, 6, 128)         2176
#
#  global_average_pooling2d_31  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_62 (Dense)            (None, 64)                8256
#
#  dense_63 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 13,894
# Trainable params: 13,894
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Training genome: NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Model params: 1692572
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 8)         80
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       25728
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       1605888
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 2)         18434
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_32  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_64 (Dense)            (None, 64)                16448
#
#  dense_65 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,692,572
# Trainable params: 1,692,572
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0257s vs `on_train_batch_end` time: 0.0315s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0257s vs `on_train_batch_end` time: 0.0315s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.7470999956130981
# Training genome: NC 2 1 sigmoid;RC 16 2 tanh;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;FL relu;
# Model params: 93542
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 2)         4
#
#  Layer_1_RC (Conv2D)         (None, 14, 14, 16)        144
#
#  Layer_2_RC (Conv2D)         (None, 7, 7, 256)         16640
#
#  Layer_3_NC (Conv2D)         (None, 7, 7, 8)           8200
#
#  Layer_4_NC (Conv2D)         (None, 7, 7, 256)         51456
#
#  global_average_pooling2d_33  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_66 (Dense)            (None, 64)                16448
#
#  dense_67 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 93,542
# Trainable params: 93,542
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Training genome: RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;
# Model params: 139274
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 13, 13, 8)         80
#
#  Layer_1_NC (Conv2D)         (None, 13, 13, 32)        9248
#
#  Layer_2_RC (Conv2D)         (None, 5, 5, 64)          32832
#
#  Layer_3_NC (Conv2D)         (None, 5, 5, 16)          36880
#
#  Layer_4_NC (Conv2D)         (None, 5, 5, 128)         51328
#
#  global_average_pooling2d_34  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_68 (Dense)            (None, 64)                8256
#
#  dense_69 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 139,274
# Trainable params: 139,274
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.70660001039505
# ['NC 2 6 relu;RC 4 7 tanh;RC 32 1 tanh;NC 128 7 tanh;NC 4 2 sigmoid;FL relu;', 'NC 128 5 sigmoid;RC 256 5 relu;NC 4 4 relu;NC 64 7 relu;RC 4 5 sigmoid;FL relu;', 'RC 8 6 sigmoid;NC 16 3 sigmoid;NC 64 1 tanh;RC 4 1 relu;NC 128 2 tanh;FL relu;', 'NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', 'NC 2 1 sigmoid;RC 16 2 tanh;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;FL relu;', 'RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;']
# [(0.4781000018119812, 0.4799833297729492, 204484), (0.10000000149011612, 0.09898333251476288, 859154), (0.10000000149011612, 0.09961666911840439, 13894), (0.7470999956130981, 0.7646333575248718, 1692572), (0.10000000149011612, 0.09956666827201843, 93542), (0.70660001039505, 0.7131166458129883, 139274)]

# %%
max(acc)
# Out:
# (0.7470999956130981, 0.7646333575248718, 1692572)

# %%
s_acc = sorted(acc)
print(s_acc)
# Out:
# [(0.10000000149011612, 0.09898333251476288, 859154), (0.10000000149011612, 0.09956666827201843, 93542), (0.10000000149011612, 0.09961666911840439, 13894), (0.4781000018119812, 0.4799833297729492, 204484), (0.70660001039505, 0.7131166458129883, 139274), (0.7470999956130981, 0.7646333575248718, 1692572)]

# %%
s , pop , acc, hist = model.search(4)
# Out:
# Architecture having Highest accuracy in samples:
#  ['NC 4 5 relu;NC 128 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;', (0.49630001187324524, 0.5029333233833313, 32262)]
# Architecture having Second highest accuracy in samples:
#  ['NC 4 5 relu;NC 128 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;', (0.49630001187324524, 0.5029333233833313, 32262)]
# 16
# NC 16 5 relu
# 8
# NC 8 3 relu
# ['NC 16 5 relu', 'NC 8 3 relu', 'RC 4 7 relu', 'RC 16 3 relu', 'FL relu', '']
# NC 16 5 relu;NC 8 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;
# Training genome: NC 16 5 relu;NC 8 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;
# Model params: 5478
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 16)        416
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 8)         1160
#
#  Layer_2_RC (Conv2D)         (None, 11, 11, 4)         1572
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 16)          592
#
#  global_average_pooling2d_8   (None, 16)               0
#  (GlobalAveragePooling2D)
#
#  dense_16 (Dense)            (None, 64)                1088
#
#  dense_17 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 5,478
# Trainable params: 5,478
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.6159999966621399
# Mutation accuracy is greater than parent adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 4 1 tanh;RC 128 3 tanh;RC 32 5 sigmoid;NC 8 3 sigmoid;FL relu;', (0.44609999656677246, 0.4487166702747345, 110714)]
# Architecture having Second highest accuracy in samples:
#  ['NC 32 7 relu;NC 256 4 sigmoid;RC 32 5 tanh;RC 256 5 sigmoid;FL relu;', (0.10000000149011612, 0.10031666606664658, 559914)]
# 256
# NC 256 1 tanh
# 16
# NC 16 3 sigmoid
# ['NC 256 1 tanh', 'RC 128 3 tanh', 'RC 32 5 sigmoid', 'NC 16 3 sigmoid', 'FL relu', '']
# NC 256 1 tanh;RC 128 3 tanh;RC 32 5 sigmoid;NC 16 3 sigmoid;FL relu;
# Training genome: NC 256 1 tanh;RC 128 3 tanh;RC 32 5 sigmoid;NC 16 3 sigmoid;FL relu;
# Model params: 404346
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 256)       512
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 128)       295040
#
#  Layer_2_RC (Conv2D)         (None, 5, 5, 32)          102432
#
#  Layer_3_NC (Conv2D)         (None, 5, 5, 16)          4624
#
#  global_average_pooling2d_9   (None, 16)               0
#  (GlobalAveragePooling2D)
#
#  dense_18 (Dense)            (None, 64)                1088
#
#  dense_19 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 404,346
# Trainable params: 404,346
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0201s vs `on_train_batch_end` time: 0.0218s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0201s vs `on_train_batch_end` time: 0.0218s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Epoch 00010: early stopping
# Best test accuracy: 0.365200012922287
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 16 5 relu;NC 8 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;', (0.6159999966621399, 0.6158833503723145, 5478)]
# Architecture having Second highest accuracy in samples:
#  ['NC 16 5 relu;NC 8 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;', (0.6159999966621399, 0.6158833503723145, 5478)]
# 2
# NC 2 5 relu
# 128
# NC 128 3 relu
# ['NC 2 5 relu', 'NC 128 3 relu', 'RC 4 7 relu', 'RC 16 3 relu', 'FL relu', '']
# NC 2 5 relu;NC 128 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;
# Training genome: NC 2 5 relu;NC 128 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;
# Model params: 29906
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 2)         52
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 128)       2432
#
#  Layer_2_RC (Conv2D)         (None, 11, 11, 4)         25092
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 16)          592
#
#  global_average_pooling2d_10  (None, 16)               0
#   (GlobalAveragePooling2D)
#
#  dense_20 (Dense)            (None, 64)                1088
#
#  dense_21 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 29,906
# Trainable params: 29,906
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0096s vs `on_train_batch_end` time: 0.0110s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0096s vs `on_train_batch_end` time: 0.0110s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Epoch 00010: early stopping
# Best test accuracy: 0.4909999966621399
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# Architecture having Second highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# 256
# NC 256 6 relu
# 1
# NC 1 3 tanh
# ['NC 256 6 relu', 'RC 2 4 tanh', 'NC 1 3 tanh', 'RC 4 5 sigmoid', 'FL relu', '']
# NC 256 6 relu;RC 2 4 tanh;NC 1 3 tanh;RC 4 5 sigmoid;FL relu;
# Training genome: NC 256 6 relu;RC 2 4 tanh;NC 1 3 tanh;RC 4 5 sigmoid;FL relu;
# Model params: 18759
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 256)       9472
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         8194
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 1)         19
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 4)           104
#
#  global_average_pooling2d_11  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_22 (Dense)            (None, 64)                320
#
#  dense_23 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 18,759
# Trainable params: 18,759
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.42260000109672546
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# Architecture having Second highest accuracy in samples:
#  ['NC 32 7 relu;NC 256 4 sigmoid;RC 32 5 tanh;RC 256 5 sigmoid;FL relu;', (0.10000000149011612, 0.10031666606664658, 559914)]
# 2
# NC 2 6 relu
# 16
# NC 16 3 tanh
# ['NC 2 6 relu', 'RC 2 4 tanh', 'NC 16 3 tanh', 'RC 4 5 sigmoid', 'FL relu', '']
# NC 2 6 relu;RC 2 4 tanh;NC 16 3 tanh;RC 4 5 sigmoid;FL relu;
# Training genome: NC 2 6 relu;RC 2 4 tanh;NC 16 3 tanh;RC 4 5 sigmoid;FL relu;
# Model params: 3018
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 2)         74
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         66
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 16)        304
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 4)           1604
#
#  global_average_pooling2d_12  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_24 (Dense)            (None, 64)                320
#
#  dense_25 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 3,018
# Trainable params: 3,018
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.45879998803138733
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# Architecture having Second highest accuracy in samples:
#  ['RC 2 7 tanh;NC 32 2 sigmoid;NC 128 1 relu;RC 32 7 relu;FL relu;', (0.10000000149011612, 0.09996666759252548, 208110)]
# 1
# NC 1 6 relu
# 32
# NC 32 3 tanh
# ['NC 1 6 relu', 'RC 2 4 tanh', 'NC 32 3 tanh', 'RC 4 5 sigmoid', 'FL relu', '']
# NC 1 6 relu;RC 2 4 tanh;NC 32 3 tanh;RC 4 5 sigmoid;FL relu;
# Training genome: NC 1 6 relu;RC 2 4 tanh;NC 32 3 tanh;RC 4 5 sigmoid;FL relu;
# Model params: 4853
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 1)         37
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         34
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 32)        608
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 4)           3204
#
#  global_average_pooling2d_13  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_26 (Dense)            (None, 64)                320
#
#  dense_27 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 4,853
# Trainable params: 4,853
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.4431000053882599
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# Architecture having Second highest accuracy in samples:
#  ['NC 4 1 tanh;RC 128 3 tanh;RC 32 5 sigmoid;NC 8 3 sigmoid;FL relu;', (0.44609999656677246, 0.4487166702747345, 110714)]
# 16
# NC 16 6 relu
# 128
# NC 128 3 tanh
# ['NC 16 6 relu', 'RC 2 4 tanh', 'NC 128 3 tanh', 'RC 4 5 sigmoid', 'FL relu', '']
# NC 16 6 relu;RC 2 4 tanh;NC 128 3 tanh;RC 4 5 sigmoid;FL relu;
# Training genome: NC 16 6 relu;RC 2 4 tanh;NC 128 3 tanh;RC 4 5 sigmoid;FL relu;
# Model params: 17312
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 16)        592
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         514
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 128)       2432
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 4)           12804
#
#  global_average_pooling2d_14  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_28 (Dense)            (None, 64)                320
#
#  dense_29 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 17,312
# Trainable params: 17,312
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.6556000113487244
# Mutation accuracy is greater than parent adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# Architecture having Second highest accuracy in samples:
#  ['NC 4 5 relu;NC 128 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;', (0.49630001187324524, 0.5029333233833313, 32262)]
# 1
# NC 1 6 relu
# 128
# NC 128 3 tanh
# ['NC 1 6 relu', 'RC 2 4 tanh', 'NC 128 3 tanh', 'RC 4 5 sigmoid', 'FL relu', '']
# NC 1 6 relu;RC 2 4 tanh;NC 128 3 tanh;RC 4 5 sigmoid;FL relu;
# Training genome: NC 1 6 relu;RC 2 4 tanh;NC 128 3 tanh;RC 4 5 sigmoid;FL relu;
# Model params: 16277
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 1)         37
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         34
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 128)       2432
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 4)           12804
#
#  global_average_pooling2d_15  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_30 (Dense)            (None, 64)                320
#
#  dense_31 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 16,277
# Trainable params: 16,277
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.49239999055862427
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 16 6 relu;RC 2 4 tanh;NC 128 3 tanh;RC 4 5 sigmoid;FL relu;', (0.6556000113487244, 0.6161500215530396, 17312)]
# Architecture having Second highest accuracy in samples:
#  ['RC 8 1 sigmoid;NC 128 2 sigmoid;NC 1 2 sigmoid;RC 1 6 relu;FL relu;', (0.10000000149011612, 0.09939999878406525, 5568)]
# 32
# NC 32 6 relu
# 16
# NC 16 3 tanh
# ['NC 32 6 relu', 'RC 2 4 tanh', 'NC 16 3 tanh', 'RC 4 5 sigmoid', 'FL relu', '']
# NC 32 6 relu;RC 2 4 tanh;NC 16 3 tanh;RC 4 5 sigmoid;FL relu;
# Training genome: NC 32 6 relu;RC 2 4 tanh;NC 16 3 tanh;RC 4 5 sigmoid;FL relu;
# Model params: 5088
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 32)        1184
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         1026
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 16)        304
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 4)           1604
#
#  global_average_pooling2d_16  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_32 (Dense)            (None, 64)                320
#
#  dense_33 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 5,088
# Trainable params: 5,088
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.5374000072479248
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# Architecture having Second highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# 32
# NC 32 6 relu
# 16
# NC 16 3 tanh
# ['NC 32 6 relu', 'RC 2 4 tanh', 'NC 16 3 tanh', 'RC 4 5 sigmoid', 'FL relu', '']
# NC 32 6 relu;RC 2 4 tanh;NC 16 3 tanh;RC 4 5 sigmoid;FL relu;
# Training genome: NC 32 6 relu;RC 2 4 tanh;NC 16 3 tanh;RC 4 5 sigmoid;FL relu;
# Model params: 5088
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 32)        1184
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         1026
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 16)        304
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 4)           1604
#
#  global_average_pooling2d_17  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_34 (Dense)            (None, 64)                320
#
#  dense_35 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 5,088
# Trainable params: 5,088
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.4165000021457672
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# Architecture having Second highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# 32
# NC 32 6 relu
# 8
# NC 8 3 tanh
# ['NC 32 6 relu', 'RC 2 4 tanh', 'NC 8 3 tanh', 'RC 4 5 sigmoid', 'FL relu', '']
# NC 32 6 relu;RC 2 4 tanh;NC 8 3 tanh;RC 4 5 sigmoid;FL relu;
# Training genome: NC 32 6 relu;RC 2 4 tanh;NC 8 3 tanh;RC 4 5 sigmoid;FL relu;
# Model params: 4136
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 32)        1184
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         1026
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 8)         152
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 4)           804
#
#  global_average_pooling2d_18  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_36 (Dense)            (None, 64)                320
#
#  dense_37 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 4,136
# Trainable params: 4,136
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.5217000246047974
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 16 5 relu;NC 8 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;', (0.6159999966621399, 0.6158833503723145, 5478)]
# Architecture having Second highest accuracy in samples:
#  ['NC 16 5 relu;NC 8 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;', (0.6159999966621399, 0.6158833503723145, 5478)]
# 8
# NC 8 5 relu
# 2
# NC 2 3 relu
# ['NC 8 5 relu', 'NC 2 3 relu', 'RC 4 7 relu', 'RC 16 3 relu', 'FL relu', '']
# NC 8 5 relu;NC 2 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;
# Training genome: NC 8 5 relu;NC 2 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;
# Model params: 3080
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 8)         208
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 2)         146
#
#  Layer_2_RC (Conv2D)         (None, 11, 11, 4)         396
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 16)          592
#
#  global_average_pooling2d_19  (None, 16)               0
#   (GlobalAveragePooling2D)
#
#  dense_38 (Dense)            (None, 64)                1088
#
#  dense_39 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 3,080
# Trainable params: 3,080
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 00009: early stopping
# Best test accuracy: 0.3456999957561493
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 16 5 relu;NC 8 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;', (0.6159999966621399, 0.6158833503723145, 5478)]
# Architecture having Second highest accuracy in samples:
#  ['NC 4 5 relu;NC 128 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;', (0.49630001187324524, 0.5029333233833313, 32262)]
# 8
# NC 8 5 relu
# 256
# NC 256 3 relu
# ['NC 8 5 relu', 'NC 256 3 relu', 'RC 4 7 relu', 'RC 16 3 relu', 'FL relu', '']
# NC 8 5 relu;NC 256 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;
# Training genome: NC 8 5 relu;NC 256 3 relu;RC 4 7 relu;RC 16 3 relu;FL relu;
# Model params: 71406
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 8)         208
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 256)       18688
#
#  Layer_2_RC (Conv2D)         (None, 11, 11, 4)         50180
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 16)          592
#
#  global_average_pooling2d_20  (None, 16)               0
#   (GlobalAveragePooling2D)
#
#  dense_40 (Dense)            (None, 64)                1088
#
#  dense_41 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 71,406
# Trainable params: 71,406
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0142s vs `on_train_batch_end` time: 0.0291s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0142s vs `on_train_batch_end` time: 0.0291s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 00008: early stopping
# Best test accuracy: 0.29260000586509705
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 64 6 relu;RC 2 4 tanh;NC 64 3 tanh;RC 4 5 sigmoid;FL relu;', (0.623199999332428, 0.6190000176429749, 13008)]
# Architecture having Second highest accuracy in samples:
#  ['RC 2 7 tanh;NC 32 2 sigmoid;NC 128 1 relu;RC 32 7 relu;FL relu;', (0.10000000149011612, 0.09996666759252548, 208110)]
# 4
# NC 4 6 relu
# 128
# NC 128 3 tanh
# ['NC 4 6 relu', 'RC 2 4 tanh', 'NC 128 3 tanh', 'RC 4 5 sigmoid', 'FL relu', '']
# NC 4 6 relu;RC 2 4 tanh;NC 128 3 tanh;RC 4 5 sigmoid;FL relu;
# Training genome: NC 4 6 relu;RC 2 4 tanh;NC 128 3 tanh;RC 4 5 sigmoid;FL relu;
# Model params: 16484
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 4)         148
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         130
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 128)       2432
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 4)           12804
#
#  global_average_pooling2d_21  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_42 (Dense)            (None, 64)                320
#
#  dense_43 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 16,484
# Trainable params: 16,484
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.5188999772071838
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 16 6 relu;RC 2 4 tanh;NC 128 3 tanh;RC 4 5 sigmoid;FL relu;', (0.6556000113487244, 0.6161500215530396, 17312)]
# Architecture having Second highest accuracy in samples:
#  ['NC 16 6 relu;RC 2 4 tanh;NC 128 3 tanh;RC 4 5 sigmoid;FL relu;', (0.6556000113487244, 0.6161500215530396, 17312)]
# 128
# NC 128 6 relu
# 256
# NC 256 3 tanh
# ['NC 128 6 relu', 'RC 2 4 tanh', 'NC 256 3 tanh', 'RC 4 5 sigmoid', 'FL relu', '']
# NC 128 6 relu;RC 2 4 tanh;NC 256 3 tanh;RC 4 5 sigmoid;FL relu;
# Training genome: NC 128 6 relu;RC 2 4 tanh;NC 256 3 tanh;RC 4 5 sigmoid;FL relu;
# Model params: 40272
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       4736
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         4098
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 256)       4864
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 4)           25604
#
#  global_average_pooling2d_22  (None, 4)                0
#   (GlobalAveragePooling2D)
#
#  dense_44 (Dense)            (None, 64)                320
#
#  dense_45 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 40,272
# Trainable params: 40,272
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-4b8e24835a5a> in <module>()
# ----> 1 s , pop , acc, hist = model.search(4)
#
# <ipython-input-11-df44c2b04832> in search(self, nsamples)
#      43       print(new_ge)
#      44       if new_ge not in self.population:
# ---> 45         r = train_model(new_ge, verbose=2, lr=1e-3, lr_decay=0.1)
#      46         if r[0]-samples[j][1][0]>0:
#      47           print("Mutation accuracy is greater than parent adding child to population")
#
# <ipython-input-5-addba1ae32ec> in train_model(modelgenome, verbose, lr, lr_decay)
#      61       verbose=0,
#      62       callbacks=callbacks,
# ---> 63       validation_data=__DS_TEST,
#      64   )
#      65   # delete model
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     349       start_time = time.time()
#     350
# --> 351     logs = self._process_logs(logs, is_batch_hook=True)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _process_logs(self, logs, is_batch_hook)
#     268     if is_batch_hook and self._batch_hooks_support_tf_logs:
#     269       return logs
# --> 270     return tf_utils.sync_to_numpy_or_python_type(logs)
#     271
#     272   def append(self, callback):
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
top_a = []
top_p = []
for idx, val in enumerate(acc):
  if val[0] > 0.60:
    top_a.append(acc[idx])
    top_p.append(pop[idx])

print(f"{top_a},\n{top_p}")
# Out:
# [(0.7470999956130981, 0.7646333575248718, 1692572), (0.70660001039505, 0.7131166458129883, 139274)],
# ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', 'RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;']

# %%
s , pop , acc, hist = model.search(4, 'addl')
# Out:
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 sigmoid;RC 256 5 relu;NC 4 4 relu;NC 64 7 relu;RC 4 5 sigmoid;FL relu;', (0.10000000149011612, 0.09898333251476288, 859154)]
# ['NC 32 1 relu', '']
# ['NC 32 1 relu', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', 'FL relu', '']
# ['NC 32 1 relu', '']
# NC 32 1 relu;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# NC 32 1 relu;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Training genome: NC 32 1 relu;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Model params: 1769356
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 32)        64
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       102528
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       1605888
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 2)         18434
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_35  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_70 (Dense)            (None, 64)                16448
#
#  dense_71 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,769,356
# Trainable params: 1,769,356
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0294s vs `on_train_batch_end` time: 0.0368s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0294s vs `on_train_batch_end` time: 0.0368s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 00006: early stopping
# Best test accuracy: 0.2653000056743622
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# ['NC 128 5 relu', '']
# ['NC 128 5 relu', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', 'FL relu', '']
# ['NC 128 5 relu', '']
# NC 128 5 relu;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# NC 128 5 relu;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Training genome: NC 128 5 relu;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Model params: 2079820
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       3328
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       409728
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       1605888
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 2)         18434
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_36  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_72 (Dense)            (None, 64)                16448
#
#  dense_73 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 2,079,820
# Trainable params: 2,079,820
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0352s vs `on_train_batch_end` time: 0.0763s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0352s vs `on_train_batch_end` time: 0.0763s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 00007: early stopping
# Best test accuracy: 0.3955000042915344
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 2 1 sigmoid;RC 16 2 tanh;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;FL relu;', (0.10000000149011612, 0.09956666827201843, 93542)]
# ['NC 16 6 sigmoid', '']
# ['NC 16 6 sigmoid', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', 'FL relu', '']
# ['NC 16 6 sigmoid', '']
# NC 16 6 sigmoid;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# NC 16 6 sigmoid;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Training genome: NC 16 6 sigmoid;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Model params: 1718684
# Model: "sequential_37"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 16)        592
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       51328
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       1605888
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 2)         18434
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_37  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_74 (Dense)            (None, 64)                16448
#
#  dense_75 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,718,684
# Trainable params: 1,718,684
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0233s vs `on_train_batch_end` time: 0.0306s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0233s vs `on_train_batch_end` time: 0.0306s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# Architecture having Second highest accuracy in samples:
#  ['NC 2 6 relu;RC 4 7 tanh;RC 32 1 tanh;NC 128 7 tanh;NC 4 2 sigmoid;FL relu;', (0.4781000018119812, 0.4799833297729492, 204484)]
# ['NC 64 3 relu', '']
# ['RC 8 3 tanh', 'NC 64 3 relu', 'RC 64 4 relu', 'NC 16 6 relu', 'NC 128 5 relu', 'FL relu', '']
# ['NC 64 3 relu', '']
# RC 8 3 tanh;NC 64 3 relu;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;
# RC 8 3 tanh;NC 64 3 relu;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;
# Training genome: RC 8 3 tanh;NC 64 3 relu;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;
# Model params: 167466
# Model: "sequential_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 13, 13, 8)         80
#
#  Layer_1_NC (Conv2D)         (None, 13, 13, 64)        4672
#
#  Layer_2_RC (Conv2D)         (None, 5, 5, 64)          65600
#
#  Layer_3_NC (Conv2D)         (None, 5, 5, 16)          36880
#
#  Layer_4_NC (Conv2D)         (None, 5, 5, 128)         51328
#
#  global_average_pooling2d_38  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_76 (Dense)            (None, 64)                8256
#
#  dense_77 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 167,466
# Trainable params: 167,466
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.44429999589920044
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 2 1 sigmoid;RC 16 2 tanh;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;FL relu;', (0.10000000149011612, 0.09956666827201843, 93542)]
# ['NC 4 2 tanh', '']
# ['NC 4 2 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', 'FL relu', '']
# ['NC 4 2 tanh', '']
# NC 4 2 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# NC 4 2 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Training genome: NC 4 2 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Model params: 1679712
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 4)         20
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       12928
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       1605888
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 2)         18434
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_39  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_78 (Dense)            (None, 64)                16448
#
#  dense_79 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,679,712
# Trainable params: 1,679,712
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0219s vs `on_train_batch_end` time: 0.0271s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0219s vs `on_train_batch_end` time: 0.0271s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 00006: early stopping
# Best test accuracy: 0.38350000977516174
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# ['NC 128 6 sigmoid', '']
# ['NC 128 6 sigmoid', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', 'FL relu', '']
# ['NC 128 6 sigmoid', '']
# NC 128 6 sigmoid;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# NC 128 6 sigmoid;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Training genome: NC 128 6 sigmoid;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Model params: 2081228
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       4736
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       409728
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       1605888
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 2)         18434
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_40  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_80 (Dense)            (None, 64)                16448
#
#  dense_81 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 2,081,228
# Trainable params: 2,081,228
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0331s vs `on_train_batch_end` time: 0.0648s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0331s vs `on_train_batch_end` time: 0.0648s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# ['NC 32 2 tanh', '']
# ['NC 32 2 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', 'FL relu', '']
# ['NC 32 2 tanh', '']
# NC 32 2 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# NC 32 2 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Training genome: NC 32 2 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Model params: 1769452
# Model: "sequential_41"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 32)        160
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       102528
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       1605888
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 2)         18434
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_41  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_82 (Dense)            (None, 64)                16448
#
#  dense_83 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,769,452
# Trainable params: 1,769,452
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0293s vs `on_train_batch_end` time: 0.0386s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0293s vs `on_train_batch_end` time: 0.0386s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 sigmoid;RC 256 5 relu;NC 4 4 relu;NC 64 7 relu;RC 4 5 sigmoid;FL relu;', (0.10000000149011612, 0.09898333251476288, 859154)]
# ['NC 32 4 tanh', '']
# ['NC 32 4 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', 'FL relu', '']
# ['NC 32 4 tanh', '']
# NC 32 4 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# NC 32 4 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Training genome: NC 32 4 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Model params: 1769836
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 32)        544
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       102528
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       1605888
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 2)         18434
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_42  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_84 (Dense)            (None, 64)                16448
#
#  dense_85 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,769,836
# Trainable params: 1,769,836
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0254s vs `on_train_batch_end` time: 0.0323s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0254s vs `on_train_batch_end` time: 0.0323s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 00007: early stopping
# Best test accuracy: 0.19910000264644623
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 2 6 relu;RC 4 7 tanh;RC 32 1 tanh;NC 128 7 tanh;NC 4 2 sigmoid;FL relu;', (0.4781000018119812, 0.4799833297729492, 204484)]
# ['NC 2 6 tanh', '']
# ['NC 2 6 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', 'FL relu', '']
# ['NC 2 6 tanh', '']
# NC 2 6 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# NC 2 6 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Training genome: NC 2 6 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Model params: 1673366
# Model: "sequential_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 2)         74
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       6528
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       1605888
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 2)         18434
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_43  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_86 (Dense)            (None, 64)                16448
#
#  dense_87 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,673,366
# Trainable params: 1,673,366
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0241s vs `on_train_batch_end` time: 0.0286s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0241s vs `on_train_batch_end` time: 0.0286s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 00007: early stopping
# Best test accuracy: 0.39169999957084656
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 2 6 relu;RC 4 7 tanh;RC 32 1 tanh;NC 128 7 tanh;NC 4 2 sigmoid;FL relu;', (0.4781000018119812, 0.4799833297729492, 204484)]
# ['NC 4 4 relu', '']
# ['NC 4 4 relu', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', 'FL relu', '']
# ['NC 4 4 relu', '']
# NC 4 4 relu;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# NC 4 4 relu;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Training genome: NC 4 4 relu;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Model params: 1679760
# Model: "sequential_44"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 4)         68
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       12928
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       1605888
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 2)         18434
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_44  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_88 (Dense)            (None, 64)                16448
#
#  dense_89 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,679,760
# Trainable params: 1,679,760
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0265s vs `on_train_batch_end` time: 0.0338s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0265s vs `on_train_batch_end` time: 0.0338s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 00005: early stopping
# Best test accuracy: 0.2903999984264374
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# Architecture having Second highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# ['NC 256 7 relu', '']
# ['RC 8 3 tanh', 'NC 256 7 relu', 'RC 64 4 relu', 'NC 16 6 relu', 'NC 128 5 relu', 'FL relu', '']
# ['NC 256 7 relu', '']
# RC 8 3 tanh;NC 256 7 relu;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;
# RC 8 3 tanh;NC 256 7 relu;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;
# Training genome: RC 8 3 tanh;NC 256 7 relu;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;
# Model params: 460010
# Model: "sequential_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 13, 13, 8)         80
#
#  Layer_1_NC (Conv2D)         (None, 13, 13, 256)       100608
#
#  Layer_2_RC (Conv2D)         (None, 5, 5, 64)          262208
#
#  Layer_3_NC (Conv2D)         (None, 5, 5, 16)          36880
#
#  Layer_4_NC (Conv2D)         (None, 5, 5, 128)         51328
#
#  global_average_pooling2d_45  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_90 (Dense)            (None, 64)                8256
#
#  dense_91 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 460,010
# Trainable params: 460,010
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0133s vs `on_train_batch_end` time: 0.0148s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0133s vs `on_train_batch_end` time: 0.0148s). Check your callbacks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-e1bfaa4bb1e6> in <module>()
# ----> 1 s , pop , acc, hist = model.search(4, 'addl')
#
# <ipython-input-33-43cd839b42be> in search(self, nsamples, mutation)
#      55       # training model on the mutated genome
#      56       if new_ge not in self.population:
# ---> 57         r = train_model(new_ge, verbose=2, lr=1e-3, lr_decay=0.1)
#      58         if r[0]-samples[j][1][0]>0:
#      59           print("Mutation accuracy is greater than parent adding child to population")
#
# <ipython-input-5-addba1ae32ec> in train_model(modelgenome, verbose, lr, lr_decay)
#      61       verbose=0,
#      62       callbacks=callbacks,
# ---> 63       validation_data=__DS_TEST,
#      64   )
#      65   # delete model
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1203       logs = None
#    1204       for epoch, iterator in data_handler.enumerate_epochs():
# -> 1205         self.reset_metrics()
#    1206         callbacks.on_epoch_begin(epoch)
#    1207         with data_handler.catch_stop_iteration():
#
# KeyboardInterrupt:

# %%
top_a = []
top_p = []
for idx, val in enumerate(acc):
  if val[0] > 0.60:
    top_a.append(acc[idx])
    top_p.append(pop[idx])

print(f"{top_a},\n{top_p}")
# Out:
# [(0.7470999956130981, 0.7646333575248718, 1692572), (0.70660001039505, 0.7131166458129883, 139274)],
# ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', 'RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;']

# %%
s , pop , acc, hist = model.search(4, 'swap')
# Out:
# Architecture having Highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# Architecture having Second highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# Swapping :
# RC 64 4 relu
# NC 16 6 relu
# RC 8 3 tanh;NC 32 6 sigmoid;NC 16 6 relu;RC 64 4 relu;NC 128 5 relu;FL relu;
# Training genome: RC 8 3 tanh;NC 32 6 sigmoid;NC 16 6 relu;RC 64 4 relu;NC 128 5 relu;FL relu;
# Model params: 258058
# Model: "sequential_46"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 13, 13, 8)         80
#
#  Layer_1_NC (Conv2D)         (None, 13, 13, 32)        9248
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 16)        18448
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 64)          16448
#
#  Layer_4_NC (Conv2D)         (None, 5, 5, 128)         204928
#
#  global_average_pooling2d_46  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_92 (Dense)            (None, 64)                8256
#
#  dense_93 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 258,058
# Trainable params: 258,058
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.478300005197525
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 2 1 sigmoid;RC 16 2 tanh;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;FL relu;', (0.10000000149011612, 0.09956666827201843, 93542)]
# Architecture having Second highest accuracy in samples:
#  ['NC 2 1 sigmoid;RC 16 2 tanh;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;FL relu;', (0.10000000149011612, 0.09956666827201843, 93542)]
# Swapping :
#
# RC 16 2 tanh
# NC 2 1 sigmoid;;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;RC 16 2 tanhFL relu;
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-41-65ae1db0a06f> in <module>()
# ----> 1 s , pop , acc, hist = model.search(4, 'swap')
#
# <ipython-input-33-43cd839b42be> in search(self, nsamples, mutation)
#      55       # training model on the mutated genome
#      56       if new_ge not in self.population:
# ---> 57         r = train_model(new_ge, verbose=2, lr=1e-3, lr_decay=0.1)
#      58         if r[0]-samples[j][1][0]>0:
#      59           print("Mutation accuracy is greater than parent adding child to population")
#
# <ipython-input-5-addba1ae32ec> in train_model(modelgenome, verbose, lr, lr_decay)
#      30   Returns a tuple: (test accuracy, train accuracy, number of parameters)
#      31   '''
# ---> 32   model = genome_to_model(modelgenome, lr=lr, lr_decay=lr_decay)
#      33   n_params = model.count_params()
#      34   if verbose > 0:
#
# <ipython-input-3-340e9b96aec5> in genome_to_model(cellgenome, lr, lr_decay)
#      64 def genome_to_model(cellgenome: str, lr: float = 2e-3, lr_decay: float = 0.05):
#      65   # parse genome
# ---> 66   parsed = parse_genome(cellgenome)
#      67   def _match_to_layer(match_tuple, idx):
#      68     return tf.keras.layers.Conv2D(
#
# <ipython-input-3-340e9b96aec5> in parse_genome(cellgenome)
#      46 def parse_genome(cellgenome: str):
#      47   if __VALIDATION_RE.fullmatch(cellgenome) is None:
# ---> 48     raise Exception(f'Invalid genome (parse error): {cellgenome}\n Please check that the genome is in the correct format.')
#      49   parse = __VALIDATION_RE_CELL.findall(cellgenome)
#      50   # check constraints
#
# Exception: Invalid genome (parse error): NC 2 1 sigmoid;;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;RC 16 2 tanhFL relu;
#  Please check that the genome is in the correct format.

# %%
s , pop , acc, hist = model.search(4, 'inversion')
# Out:
# Architecture having Highest accuracy in samples:
#  ['NC 128 5 sigmoid;RC 256 5 relu;NC 4 4 relu;NC 64 7 relu;RC 4 5 sigmoid;FL relu;', (0.10000000149011612, 0.09898333251476288, 859154)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 sigmoid;RC 256 5 relu;NC 4 4 relu;NC 64 7 relu;RC 4 5 sigmoid;FL relu;', (0.10000000149011612, 0.09898333251476288, 859154)]
# ['NC 128 5 sigmoid', 'RC 256 5 relu', 'NC 4 4 relu', 'NC 64 7 relu', 'RC 4 5 sigmoid', '']
# FL relu
# 1
# 5
# ['RC 256 5 relu', 'NC 4 4 relu', 'NC 64 7 relu', 'RC 4 5 sigmoid']
# NC 128 5 sigmoid;RC 4 5 sigmoid;NC 64 7 relu;NC 4 4 relu;RC 256 5 relu;FL relu;
# Training genome: NC 128 5 sigmoid;RC 4 5 sigmoid;NC 64 7 relu;NC 4 4 relu;RC 256 5 relu;FL relu;
# Model params: 75794
# Model: "sequential_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       3328
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 4)         12804
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 64)        12608
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 4)         4100
#
#  Layer_4_RC (Conv2D)         (None, 4, 4, 256)         25856
#
#  global_average_pooling2d_47  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_94 (Dense)            (None, 64)                16448
#
#  dense_95 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 75,794
# Trainable params: 75,794
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 sigmoid;RC 256 5 relu;NC 4 4 relu;NC 64 7 relu;RC 4 5 sigmoid;FL relu;', (0.10000000149011612, 0.09898333251476288, 859154)]
# ['RC 8 3 tanh', 'NC 32 6 sigmoid', 'RC 64 4 relu', 'NC 16 6 relu', 'NC 128 5 relu', '']
# FL relu
# 0
# 5
# ['RC 8 3 tanh', 'NC 32 6 sigmoid', 'RC 64 4 relu', 'NC 16 6 relu', 'NC 128 5 relu']
# NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;
# Training genome: NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;
# Model params: 170818
# Model: "sequential_48"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       3328
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 16)        73744
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 64)        16448
#
#  Layer_3_NC (Conv2D)         (None, 13, 13, 32)        73760
#
#  Layer_4_RC (Conv2D)         (None, 6, 6, 8)           2312
#
#  global_average_pooling2d_48  (None, 8)                0
#   (GlobalAveragePooling2D)
#
#  dense_96 (Dense)            (None, 64)                576
#
#  dense_97 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 170,818
# Trainable params: 170,818
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0250s vs `on_train_batch_end` time: 0.0317s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0250s vs `on_train_batch_end` time: 0.0317s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.7447999715805054
# Mutation accuracy is greater than parent adding child to population
# Architecture having Highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# Architecture having Second highest accuracy in samples:
#  ['RC 8 6 sigmoid;NC 16 3 sigmoid;NC 64 1 tanh;RC 4 1 relu;NC 128 2 tanh;FL relu;', (0.10000000149011612, 0.09961666911840439, 13894)]
# ['RC 8 3 tanh', 'NC 32 6 sigmoid', 'RC 64 4 relu', 'NC 16 6 relu', 'NC 128 5 relu', '']
# FL relu
# 1
# 3
# ['NC 32 6 sigmoid', 'RC 64 4 relu']
# RC 8 3 tanh;RC 64 4 relu;NC 32 6 sigmoid;NC 16 6 relu;NC 128 5 relu;FL relu;
# Training genome: RC 8 3 tanh;RC 64 4 relu;NC 32 6 sigmoid;NC 16 6 relu;NC 128 5 relu;FL relu;
# Model params: 160778
# Model: "sequential_49"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 13, 13, 8)         80
#
#  Layer_1_RC (Conv2D)         (None, 5, 5, 64)          8256
#
#  Layer_2_NC (Conv2D)         (None, 5, 5, 32)          73760
#
#  Layer_3_NC (Conv2D)         (None, 5, 5, 16)          18448
#
#  Layer_4_NC (Conv2D)         (None, 5, 5, 128)         51328
#
#  global_average_pooling2d_49  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_98 (Dense)            (None, 64)                8256
#
#  dense_99 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 160,778
# Trainable params: 160,778
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Epoch 00010: early stopping
# Best test accuracy: 0.5809999704360962
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 2 6 relu;RC 4 7 tanh;RC 32 1 tanh;NC 128 7 tanh;NC 4 2 sigmoid;FL relu;', (0.4781000018119812, 0.4799833297729492, 204484)]
# Architecture having Second highest accuracy in samples:
#  ['RC 8 6 sigmoid;NC 16 3 sigmoid;NC 64 1 tanh;RC 4 1 relu;NC 128 2 tanh;FL relu;', (0.10000000149011612, 0.09961666911840439, 13894)]
# ['NC 2 6 relu', 'RC 4 7 tanh', 'RC 32 1 tanh', 'NC 128 7 tanh', 'NC 4 2 sigmoid', '']
# FL relu
# 3
# 5
# ['NC 128 7 tanh', 'NC 4 2 sigmoid']
# NC 2 6 relu;RC 4 7 tanh;RC 32 1 tanh;NC 4 2 sigmoid;NC 128 7 tanh;FL relu;
# Training genome: NC 2 6 relu;RC 4 7 tanh;RC 32 1 tanh;NC 4 2 sigmoid;NC 128 7 tanh;FL relu;
# Model params: 35268
# Model: "sequential_50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 2)         74
#
#  Layer_1_RC (Conv2D)         (None, 11, 11, 4)         396
#
#  Layer_2_RC (Conv2D)         (None, 6, 6, 32)          160
#
#  Layer_3_NC (Conv2D)         (None, 6, 6, 4)           516
#
#  Layer_4_NC (Conv2D)         (None, 6, 6, 128)         25216
#
#  global_average_pooling2d_50  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_100 (Dense)           (None, 64)                8256
#
#  dense_101 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 35,268
# Trainable params: 35,268
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# ['NC 8 3 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', '']
# FL relu
# 0
# 1
# ['NC 8 3 tanh']
# NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# ['NC 8 3 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', '']
# FL relu
# 3
# 4
# ['NC 2 6 sigmoid']
# NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# ['NC 8 3 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', '']
# FL relu
# 1
# 2
# ['RC 128 5 tanh']
# NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;', (0.7447999715805054, 0.748116672039032, 170818)]
# ['NC 8 3 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', '']
# FL relu
# 2
# 5
# ['NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid']
# NC 8 3 tanh;RC 128 5 tanh;RC 256 7 sigmoid;NC 2 6 sigmoid;NC 256 7 relu;FL relu;
# Training genome: NC 8 3 tanh;RC 128 5 tanh;RC 256 7 sigmoid;NC 2 6 sigmoid;NC 256 7 relu;FL relu;
# Model params: 1692572
# Model: "sequential_51"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 8)         80
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 128)       25728
#
#  Layer_2_RC (Conv2D)         (None, 3, 3, 256)         1605888
#
#  Layer_3_NC (Conv2D)         (None, 3, 3, 2)           18434
#
#  Layer_4_NC (Conv2D)         (None, 3, 3, 256)         25344
#
#  global_average_pooling2d_51  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_102 (Dense)           (None, 64)                16448
#
#  dense_103 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 1,692,572
# Trainable params: 1,692,572
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0124s vs `on_train_batch_end` time: 0.0153s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0124s vs `on_train_batch_end` time: 0.0153s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 00009: early stopping
# Best test accuracy: 0.5967000126838684
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# ['NC 8 3 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', '']
# FL relu
# 0
# 4
# ['NC 8 3 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid']
# NC 2 6 sigmoid;NC 256 7 relu;RC 128 5 tanh;NC 8 3 tanh;RC 256 7 sigmoid;FL relu;
# Training genome: NC 2 6 sigmoid;NC 256 7 relu;RC 128 5 tanh;NC 8 3 tanh;RC 256 7 sigmoid;FL relu;
# Model params: 971676
# Model: "sequential_52"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 2)         74
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 256)       25344
#
#  Layer_2_RC (Conv2D)         (None, 12, 12, 128)       819328
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 8)         9224
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         100608
#
#  global_average_pooling2d_52  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_104 (Dense)           (None, 64)                16448
#
#  dense_105 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 971,676
# Trainable params: 971,676
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0218s vs `on_train_batch_end` time: 0.0408s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0218s vs `on_train_batch_end` time: 0.0408s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;', (0.7447999715805054, 0.748116672039032, 170818)]
# Architecture having Second highest accuracy in samples:
#  ['NC 2 6 relu;RC 4 7 tanh;RC 32 1 tanh;NC 128 7 tanh;NC 4 2 sigmoid;FL relu;', (0.4781000018119812, 0.4799833297729492, 204484)]
# ['NC 128 5 relu', 'NC 16 6 relu', 'RC 64 4 relu', 'NC 32 6 sigmoid', 'RC 8 3 tanh', '']
# FL relu
# 4
# 5
# ['RC 8 3 tanh']
# NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;
# Architecture having Highest accuracy in samples:
#  ['NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;', (0.7447999715805054, 0.748116672039032, 170818)]
# Architecture having Second highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# ['NC 128 5 relu', 'NC 16 6 relu', 'RC 64 4 relu', 'NC 32 6 sigmoid', 'RC 8 3 tanh', '']
# FL relu
# 1
# 3
# ['NC 16 6 relu', 'RC 64 4 relu']
# NC 128 5 relu;RC 64 4 relu;NC 16 6 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;
# Training genome: NC 128 5 relu;RC 64 4 relu;NC 16 6 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;
# Model params: 193346
# Model: "sequential_53"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       3328
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 64)        131136
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 16)        36880
#
#  Layer_3_NC (Conv2D)         (None, 13, 13, 32)        18464
#
#  Layer_4_RC (Conv2D)         (None, 6, 6, 8)           2312
#
#  global_average_pooling2d_53  (None, 8)                0
#   (GlobalAveragePooling2D)
#
#  dense_106 (Dense)           (None, 64)                576
#
#  dense_107 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 193,346
# Trainable params: 193,346
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0147s vs `on_train_batch_end` time: 0.0208s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0147s vs `on_train_batch_end` time: 0.0208s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 00006: early stopping
# Best test accuracy: 0.29589998722076416
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', (0.7470999956130981, 0.7646333575248718, 1692572)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;', (0.7447999715805054, 0.748116672039032, 170818)]
# ['NC 8 3 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid', 'RC 256 7 sigmoid', '']
# FL relu
# 0
# 4
# ['NC 8 3 tanh', 'RC 128 5 tanh', 'NC 256 7 relu', 'NC 2 6 sigmoid']
# NC 2 6 sigmoid;NC 256 7 relu;RC 128 5 tanh;NC 8 3 tanh;RC 256 7 sigmoid;FL relu;
# Training genome: NC 2 6 sigmoid;NC 256 7 relu;RC 128 5 tanh;NC 8 3 tanh;RC 256 7 sigmoid;FL relu;
# Model params: 971676
# Model: "sequential_54"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 2)         74
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 256)       25344
#
#  Layer_2_RC (Conv2D)         (None, 12, 12, 128)       819328
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 8)         9224
#
#  Layer_4_RC (Conv2D)         (None, 3, 3, 256)         100608
#
#  global_average_pooling2d_54  (None, 256)              0
#   (GlobalAveragePooling2D)
#
#  dense_108 (Dense)           (None, 64)                16448
#
#  dense_109 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 971,676
# Trainable params: 971,676
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0252s vs `on_train_batch_end` time: 0.0535s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0252s vs `on_train_batch_end` time: 0.0535s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 2 1 sigmoid;RC 16 2 tanh;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;FL relu;', (0.10000000149011612, 0.09956666827201843, 93542)]
# Architecture having Second highest accuracy in samples:
#  ['NC 2 1 sigmoid;RC 16 2 tanh;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;FL relu;', (0.10000000149011612, 0.09956666827201843, 93542)]
# ['NC 2 1 sigmoid', 'RC 16 2 tanh', 'RC 256 2 relu', 'NC 8 2 relu', 'NC 256 5 sigmoid', '']
# FL relu
# 3
# 4
# ['NC 8 2 relu']
# NC 2 1 sigmoid;RC 16 2 tanh;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;FL relu;
# Architecture having Highest accuracy in samples:
#  ['NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;', (0.7447999715805054, 0.748116672039032, 170818)]
# Architecture having Second highest accuracy in samples:
#  ['NC 2 6 relu;RC 4 7 tanh;RC 32 1 tanh;NC 128 7 tanh;NC 4 2 sigmoid;FL relu;', (0.4781000018119812, 0.4799833297729492, 204484)]
# ['NC 128 5 relu', 'NC 16 6 relu', 'RC 64 4 relu', 'NC 32 6 sigmoid', 'RC 8 3 tanh', '']
# FL relu
# 3
# 5
# ['NC 32 6 sigmoid', 'RC 8 3 tanh']
# NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;RC 8 3 tanh;NC 32 6 sigmoid;FL relu;
# Training genome: NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;RC 8 3 tanh;NC 32 6 sigmoid;FL relu;
# Model params: 110146
# Model: "sequential_55"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       3328
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 16)        73744
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 64)        16448
#
#  Layer_3_RC (Conv2D)         (None, 6, 6, 8)           4616
#
#  Layer_4_NC (Conv2D)         (None, 6, 6, 32)          9248
#
#  global_average_pooling2d_55  (None, 32)               0
#   (GlobalAveragePooling2D)
#
#  dense_110 (Dense)           (None, 64)                2112
#
#  dense_111 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 110,146
# Trainable params: 110,146
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0237s vs `on_train_batch_end` time: 0.0299s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0237s vs `on_train_batch_end` time: 0.0299s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.713100016117096
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 sigmoid;RC 256 5 relu;NC 4 4 relu;NC 64 7 relu;RC 4 5 sigmoid;FL relu;', (0.10000000149011612, 0.09898333251476288, 859154)]
# ['RC 8 3 tanh', 'NC 32 6 sigmoid', 'RC 64 4 relu', 'NC 16 6 relu', 'NC 128 5 relu', '']
# FL relu
# 3
# 4
# ['NC 16 6 relu']
# RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;
# Architecture having Highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 sigmoid;RC 256 5 relu;NC 4 4 relu;NC 64 7 relu;RC 4 5 sigmoid;FL relu;', (0.10000000149011612, 0.09898333251476288, 859154)]
# ['RC 8 3 tanh', 'NC 32 6 sigmoid', 'RC 64 4 relu', 'NC 16 6 relu', 'NC 128 5 relu', '']
# FL relu
# 0
# 3
# ['RC 8 3 tanh', 'NC 32 6 sigmoid', 'RC 64 4 relu']
# RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;NC 16 6 relu;NC 128 5 relu;FL relu;
# Training genome: RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;NC 16 6 relu;NC 128 5 relu;FL relu;
# Model params: 142018
# Model: "sequential_56"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 13, 13, 64)        1088
#
#  Layer_1_NC (Conv2D)         (None, 13, 13, 32)        73760
#
#  Layer_2_RC (Conv2D)         (None, 6, 6, 8)           2312
#
#  Layer_3_NC (Conv2D)         (None, 6, 6, 16)          4624
#
#  Layer_4_NC (Conv2D)         (None, 6, 6, 128)         51328
#
#  global_average_pooling2d_56  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_112 (Dense)           (None, 64)                8256
#
#  dense_113 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 142,018
# Trainable params: 142,018
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.5770999789237976
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# Architecture having Second highest accuracy in samples:
#  ['NC 2 1 sigmoid;RC 16 2 tanh;RC 256 2 relu;NC 8 2 relu;NC 256 5 sigmoid;FL relu;', (0.10000000149011612, 0.09956666827201843, 93542)]
# ['RC 8 3 tanh', 'NC 32 6 sigmoid', 'RC 64 4 relu', 'NC 16 6 relu', 'NC 128 5 relu', '']
# FL relu
# 2
# 3
# ['RC 64 4 relu']
# RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;
# Architecture having Highest accuracy in samples:
#  ['NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;', (0.7447999715805054, 0.748116672039032, 170818)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;', (0.7447999715805054, 0.748116672039032, 170818)]
# ['NC 128 5 relu', 'NC 16 6 relu', 'RC 64 4 relu', 'NC 32 6 sigmoid', 'RC 8 3 tanh', '']
# FL relu
# 3
# 5
# ['NC 32 6 sigmoid', 'RC 8 3 tanh']
# NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;RC 8 3 tanh;NC 32 6 sigmoid;FL relu;
# Training genome: NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;RC 8 3 tanh;NC 32 6 sigmoid;FL relu;
# Model params: 110146
# Model: "sequential_57"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       3328
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 16)        73744
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 64)        16448
#
#  Layer_3_RC (Conv2D)         (None, 6, 6, 8)           4616
#
#  Layer_4_NC (Conv2D)         (None, 6, 6, 32)          9248
#
#  global_average_pooling2d_57  (None, 32)               0
#   (GlobalAveragePooling2D)
#
#  dense_114 (Dense)           (None, 64)                2112
#
#  dense_115 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 110,146
# Trainable params: 110,146
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0208s vs `on_train_batch_end` time: 0.0300s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0208s vs `on_train_batch_end` time: 0.0300s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.6154000163078308
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;', (0.7447999715805054, 0.748116672039032, 170818)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;', (0.7447999715805054, 0.748116672039032, 170818)]
# ['NC 128 5 relu', 'NC 16 6 relu', 'RC 64 4 relu', 'NC 32 6 sigmoid', 'RC 8 3 tanh', '']
# FL relu
# 3
# 5
# ['NC 32 6 sigmoid', 'RC 8 3 tanh']
# NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;RC 8 3 tanh;NC 32 6 sigmoid;FL relu;
# Training genome: NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;RC 8 3 tanh;NC 32 6 sigmoid;FL relu;
# Model params: 110146
# Model: "sequential_58"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       3328
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 16)        73744
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 64)        16448
#
#  Layer_3_RC (Conv2D)         (None, 6, 6, 8)           4616
#
#  Layer_4_NC (Conv2D)         (None, 6, 6, 32)          9248
#
#  global_average_pooling2d_58  (None, 32)               0
#   (GlobalAveragePooling2D)
#
#  dense_116 (Dense)           (None, 64)                2112
#
#  dense_117 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 110,146
# Trainable params: 110,146
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0223s vs `on_train_batch_end` time: 0.0307s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0223s vs `on_train_batch_end` time: 0.0307s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.5684000253677368
# Mutation accuracy is less than parent not adding child to population
# Architecture having Highest accuracy in samples:
#  ['RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', (0.70660001039505, 0.7131166458129883, 139274)]
# Architecture having Second highest accuracy in samples:
#  ['NC 128 5 sigmoid;RC 256 5 relu;NC 4 4 relu;NC 64 7 relu;RC 4 5 sigmoid;FL relu;', (0.10000000149011612, 0.09898333251476288, 859154)]
# ['RC 8 3 tanh', 'NC 32 6 sigmoid', 'RC 64 4 relu', 'NC 16 6 relu', 'NC 128 5 relu', '']
# FL relu
# 1
# 5
# ['NC 32 6 sigmoid', 'RC 64 4 relu', 'NC 16 6 relu', 'NC 128 5 relu']
# RC 8 3 tanh;NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;FL relu;
# Training genome: RC 8 3 tanh;NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;FL relu;
# Model params: 192522
# Model: "sequential_59"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 13, 13, 8)         80
#
#  Layer_1_NC (Conv2D)         (None, 13, 13, 128)       25728
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 16)        73744
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 64)          16448
#
#  Layer_4_NC (Conv2D)         (None, 5, 5, 32)          73760
#
#  global_average_pooling2d_59  (None, 32)               0
#   (GlobalAveragePooling2D)
#
#  dense_118 (Dense)           (None, 64)                2112
#
#  dense_119 (Dense)           (None, 10)                650
#
# =================================================================
# Total params: 192,522
# Trainable params: 192,522
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-41482955e905> in <module>()
# ----> 1 s , pop , acc, hist = model.search(4, 'inversion')
#
# <ipython-input-33-43cd839b42be> in search(self, nsamples, mutation)
#      55       # training model on the mutated genome
#      56       if new_ge not in self.population:
# ---> 57         r = train_model(new_ge, verbose=2, lr=1e-3, lr_decay=0.1)
#      58         if r[0]-samples[j][1][0]>0:
#      59           print("Mutation accuracy is greater than parent adding child to population")
#
# <ipython-input-5-addba1ae32ec> in train_model(modelgenome, verbose, lr, lr_decay)
#      61       verbose=0,
#      62       callbacks=callbacks,
# ---> 63       validation_data=__DS_TEST,
#      64   )
#      65   # delete model
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     349       start_time = time.time()
#     350
# --> 351     logs = self._process_logs(logs, is_batch_hook=True)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _process_logs(self, logs, is_batch_hook)
#     268     if is_batch_hook and self._batch_hooks_support_tf_logs:
#     269       return logs
# --> 270     return tf_utils.sync_to_numpy_or_python_type(logs)
#     271
#     272   def append(self, callback):
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
top_a = []
top_p = []
for idx, val in enumerate(acc):
  if val[0] > 0.60:
    top_a.append(acc[idx])
    top_p.append(pop[idx])

print(f"{top_a},\n{top_p}")
# Out:
# [(0.7470999956130981, 0.7646333575248718, 1692572), (0.70660001039505, 0.7131166458129883, 139274), (0.7447999715805054, 0.748116672039032, 170818)],
# ['NC 8 3 tanh;RC 128 5 tanh;NC 256 7 relu;NC 2 6 sigmoid;RC 256 7 sigmoid;FL relu;', 'RC 8 3 tanh;NC 32 6 sigmoid;RC 64 4 relu;NC 16 6 relu;NC 128 5 relu;FL relu;', 'NC 128 5 relu;NC 16 6 relu;RC 64 4 relu;NC 32 6 sigmoid;RC 8 3 tanh;FL relu;']
