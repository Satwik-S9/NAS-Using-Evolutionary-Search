# %% [markdown]
# # Project Question
#
# > Create a search function to search in a NAS space for the best performing **CNN architecture** on fashion-mnist.
#
# Your task is to create a search function which searches for the model genome string that provides the best accuracy while using the least number of parameters.
#
# Your program will return a model genome string (described below) which can be fed to a train function (provided below) to get the lowest parameter count and best accuracy after training.
#
# **This is an open research problem**. You can use any method to search for the best genome and there might not be a perfect solution possible (prefect in the sense of maximum accuracy with minimum parameters). You will likely find tradeoffs between accuracy and number of parameters and you must balance such tradeoffs at your discretion.
#
# > Aim for a search function that finds a genome with accuracy at least 75%.
#
# You are encouraged to experiment with different techniques and apply your intuition to find a good search algorithm.

# %% [markdown]
# ## CNN Architecture Constraints
#
# Your search algorithm should search for models with the following basic structure.
#
# Sequential model (no skip connections) having the following layers,
# - Any number of normal(NC) CNN layers
#   - `torch.nn.Conv2d` or `tf.keras.layers.Conv2D`
#   - A normal CNN layer has the following constraints,
#     - `stride=1`
#     - `padding=same`
#     - `1 <= kernel size < 8`
#     - Any of the following activation functions,
#       - relu
#       - sigmoid
#       - tanh
#       - swish
#       - gelu
# - **Exactly** 2 reduction(RC) CNN layers
#   - `torch.nn.Conv2d` or `tf.keras.layers.Conv2D`
#   - A reduction layer has the **same** constraints as the normal layer except the following,
#     - `stride=2`
#     - `padding=valid`
# - **Exactly** the following structure as the **final layers**,
#   - First, a Global Average Pooling 2D layer.
#     - `torch.nn.AvgPool2d(kernel_size=layer_input_image_size)` or `tf.keras.layers.GlobalAveragePooling2D`
#   - Then, a Fully Connected/Dense layer with 64 units (such that output is shape `(batch_size, 10)`)
#     - This layer can have any of the allowed activations in NC layer but all final layers must use same activation.
#     - `torch.nn.Linear(64)` or `tf.keras.layers.Dense(64)`
#   - Then, a Fully Connected/Dense layer with 10 units (such that output is shape `(batch_size, 10)`)
#     - This layer can have any of the allowed activations in NC layer but all final layers must use same activation.
#     - `torch.nn.Linear(10)` or `tf.keras.layers.Dense(10)`
#
#
# The normal(NC) and reduction(RC) layers can be in **any order** as long as the constraints above are maintained.
#
# The final layers of you model should be exactly as mentioned in these constraints.
#
# All of the above contraints **apply only to your final output**. During searching for the best architecture you can do whatever you want.
#
# Once your algorithm finds the best architecture, it should represent the architecture as a genome string (explained below) which will be fed to the training function given below to get the final accuracy.

# %%
#@title Run to setup question dependencies
# !pip install --upgrade -q tfds-nightly tensorflow-addons
# Out:
#      |████████████████████████████████| 4.0 MB 4.3 MB/s
#      |████████████████████████████████| 1.1 MB 40.5 MB/s

# %%
#@title Run to download and prepare dataset
#@markdown - https://www.tensorflow.org/datasets/catalog/fashion_mnist

import tensorflow as tf
import tensorflow_datasets as tfds

(__DS_TRAIN, __DS_TEST), __DS_INFO = tfds.load(
    'fashion_mnist',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

_ = tfds.show_examples(__DS_TEST, __DS_INFO)

# Prepare splits
def __normalize_img(image, label):
  """Normalizes images: `uint8` -> `float32`."""
  return tf.cast(image, tf.float32) / 255., label
# Prepare train split
__DS_TRAIN = __DS_TRAIN.map(__normalize_img, num_parallel_calls=tf.data.experimental.AUTOTUNE)
__DS_TRAIN = __DS_TRAIN.cache()
__DS_TRAIN = __DS_TRAIN.shuffle(__DS_INFO.splits['train'].num_examples)
__DS_TRAIN = __DS_TRAIN.batch(128)
__DS_TRAIN = __DS_TRAIN.prefetch(tf.data.experimental.AUTOTUNE)
# Prepare test split
__DS_TEST = __DS_TEST.map(__normalize_img, num_parallel_calls=tf.data.experimental.AUTOTUNE)
__DS_TEST = __DS_TEST.batch(128)
__DS_TEST = __DS_TEST.cache()
__DS_TEST = __DS_TEST.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# Downloading and preparing dataset 29.45 MiB (download: 29.45 MiB, generated: 36.42 MiB, total: 65.87 MiB) to /root/tensorflow_datasets/fashion_mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling fashion_mnist-train.tfrecord...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling fashion_mnist-test.tfrecord...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset fashion_mnist downloaded and prepared to /root/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.

# %%
#@title Run to setup model genome processing code
#@markdown A model genome is a string having `;` seperated parts where each part describes a specific layer.
#@markdown 
#@markdown For eg., this cell genome has 1 normal convolution layer followed by 2 reduction convolution layers and relu activation in the final layer.
#@markdown ```
#@markdown NC 10 2 sigmoid;RC 10 3 relu;RC 10 3 relu;FL relu;
#@markdown ```
#@markdown 
#@markdown In the above example the normal layer has 10 CNN filters having a kernel size of 2 and sigmoid activation. After the normal layer it has 2 reduction layers with 10 filters, kernel size of 3 and relu activation function. This example therefore has 3 internal layers. Finally, the genome specifies `relu` activation for the final layer(FL).
#@markdown 
#@markdown The format for each genome part for `NC` and `RC` layers is as follows,
#@markdown ```
#@markdown <NC or RC> <no. of CNN filters> <kernel size LESS THAN 8> <activation function>;
#@markdown ```
#@markdown After all `NC` and `RC` genome parts the final layer genome part has the following format,
#@markdown ```
#@markdown FL <activation function>;
#@markdown ```
#@markdown With the above, the full genome format is,
#@markdown ```
#@markdown <any number of FC/RC genome parts>;FL <activation function>;
#@markdown ```
#@markdown Here,
#@markdown - `NC` is normal genome and `RC` is reduction genome. Normal genomes keep the dimentions of the input image intact (i.e. `stride=1`), while reduction genomes make the output image dimension half of the input dimension.
#@markdown  - See the constraints section above for specific details.
#@markdown - Every genome **MUST** have **EXACTLY 2** `RC` parts. These `RC` parts can be placed anywhere in the genome.

import tensorflow as tf
import tensorflow_addons as tfa
import re
from collections import Counter

__ALLOWED_ACTIVATIONS = [
                         'relu',
                         'sigmoid',
                         'tanh',
                         'swish',
                         'gelu',
]
__VALIDATION_RE_CELL = re.compile(f'((?P<type>NC|RC) (?P<filters>\d+?) (?P<kernel>[1234567]) (?P<activation>{"|".join(__ALLOWED_ACTIVATIONS)});)+?')
__VALIDATION_RE_FL = re.compile(f'FL (?P<fl_activation>{"|".join(__ALLOWED_ACTIVATIONS)});')
__VALIDATION_RE = re.compile(f'((?P<type>NC|RC) (?P<filters>\d+?) (?P<kernel>[1234567]) (?P<activation>{"|".join(__ALLOWED_ACTIVATIONS)});)+?FL (?P<fl_activation>{"|".join(__ALLOWED_ACTIVATIONS)});')

__SAMPLE_GENOME = 'NC 1 1 sigmoid;RC 2 3 relu;RC 5 7 relu;'

def parse_genome(cellgenome: str):
  if __VALIDATION_RE.fullmatch(cellgenome) is None:
    raise Exception(f'Invalid genome (parse error): {cellgenome}\n Please check that the genome is in the correct format.')
  parse = __VALIDATION_RE_CELL.findall(cellgenome)
  # check constraints
  type_count = Counter()
  for idx, cell in enumerate(parse):
    type_count.update([cell[1]])
    filter = int(cell[2])
    kernel = int(cell[3])
    if filter < 1:
      raise Exception(f'Invalid filter size {filter} for layer {idx+1}.')
    if kernel < 1 or kernel > 7:
      raise Exception(f'Invalid kernel size {filter} for layer {idx+1}.')
  if type_count['RC'] != 2:
    raise Exception(f'Genome must have exacly 2 RC parts. Your genome has {type_count["RC"]} RC parts.')
  return parse + __VALIDATION_RE_FL.findall(cellgenome)

def genome_to_model(cellgenome: str, lr: float = 2e-3, lr_decay: float = 0.05):
  # parse genome
  parsed = parse_genome(cellgenome)
  def _match_to_layer(match_tuple, idx):
    return tf.keras.layers.Conv2D(
        filters = int(match_tuple[2]),
        kernel_size = int(match_tuple[3]),
        strides = 1 if match_tuple[1] == 'NC' else 2,
        name = f'Layer_{idx}_{match_tuple[1]}',
        activation = match_tuple[4],
        padding = 'same' if match_tuple[1] == 'NC' else 'valid',
    )
  # create model object
  model = tf.keras.Sequential(
    [
      *[_match_to_layer(cell, idx) for idx, cell in enumerate(parsed[:-1])],
      tf.keras.layers.GlobalAveragePooling2D(),
      tf.keras.layers.Dense(
          64,
          activation=parsed[-1],
      ),
      tf.keras.layers.Dense(
          __DS_INFO.features['label'].num_classes,
          activation=parsed[-1],
      ),
    ]
  )
  # compile the model
  model.compile(
      optimizer=tfa.optimizers.AdamW(
          learning_rate=tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=lr,
            decay_steps=len(__DS_TRAIN)*10,
            decay_rate=lr_decay,
          ),
          weight_decay=1e-9,
      ),
      loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
      metrics=['accuracy']
  )
  model.build((None, *__DS_INFO.features['image'].shape))
  return model

# %%
#@title Use this form to validate a genome and see the resulting model
#@markdown Enter your genome in this text field and then run this cell.
__fr_model_genome = "NC 256 5 tanh;RC 64 5 relu;NC 256 5 tanh;NC 4 3 tanh;RC 16 3 tanh;FL relu;" #@param {type:"string"}

try:
  __fr_model = genome_to_model(__fr_model_genome)
  __fr_model.summary()
  del __fr_model
except Exception as e:
  print(e)
  print()
  print(f'Your input genome: {__fr_model_genome}')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 256)       6656
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 64)        409664
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       409856
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 4)         9220
#
#  Layer_4_RC (Conv2D)         (None, 5, 5, 16)          592
#
#  global_average_pooling2d (G  (None, 16)               0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                1088
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 837,726
# Trainable params: 837,726
# Non-trainable params: 0
# _________________________________________________________________

# %%
#@title Run to setup model training code
#@markdown You are provided with two functions,
#@markdown - **`get_model_parameters(model_genome: str)`**: This function accepts the model genome string and returns the number of parameters that the model will have. You can use this function to query for the number of parameters without training the model entirely.
#@markdown 
#@markdown    **Returns**: A single integer representing the number of parameters in the model.

#@markdown - **`train_model(model_genome: str, verbose: int = 1, lr: float = None, lr_decacy: float = None)`**: This function accepts the model genome string and trains the model on the Fashion-MNIST dataset. You must use this function to train models based on your genome string.
#@markdown 
#@markdown      - If `verbose` is `0` then this function does not print anything while training
#@markdown      - If `verbose` is `1` then it prints the training progess on each call and the final test accuracy.
#@markdown      - If `verbose` is `2` then it prints everything from `varbose=1` and also prints the model summary (structure).
#@markdown 
#@markdown  It accepts a learning rate (`lr`) and a learning rate exponential decay rate (`lr_decay`). You do not need to provide values for `lr` and `lr_decay`, the default values are tuned to give good performance  3~10 layer networks. Below you will find some example values for a sample shallow network and a sample deep network.
#@markdown 
#@markdown   **Returns**: A tuple of `(test accuracy, train accuracy, number of parameters)`.
#@markdown 
#@markdown Using the above two functions you must create a search method to search for a model genome which gives the maximum **test accuracy**. You are given the train accuracy to identify _overfitting_ if you wish to do so. You can also use the number of parameters to prefer models having fewer parameters and find a good balance between test accuracy and number of parameters.

def get_model_parameters(modelgenome: str):
  '''
  Returns the number of parameters that this genome creates.
  '''
  model = genome_to_model(modelgenome)
  return model.count_params()

def train_model(modelgenome: str, verbose: int = 1, lr: float = None, lr_decay: float = None):
  '''
  Accepts a genome string and trains the corresponding model on Fashion MNIST dataset.
  Thorws exceptions if the provided genome is invalid.
  Returns a tuple: (test accuracy, train accuracy, number of parameters)
  '''
  model = genome_to_model(modelgenome, lr=lr, lr_decay=lr_decay)
  n_params = model.count_params()
  if verbose > 0:
    print(f'Training genome: {modelgenome}')
    print(f'Model params: {n_params}')
  if verbose > 1:
    model.summary()
  # train model
  callbacks = [
    tf.keras.callbacks.EarlyStopping(
      monitor='val_loss',
      mode='min',
      baseline=10.0,
      patience=2,
      min_delta=0.005,
      verbose=verbose,
    )
  ]
  if verbose > 0:
    callbacks.append(
      tfa.callbacks.TQDMProgressBar(
        update_per_second = 1,
        leave_epoch_progress = verbose > 1,
        leave_overall_progress = verbose > 1,
      )
    )
  ret = model.fit(
      __DS_TRAIN,
      epochs=10,
      verbose=0,
      callbacks=callbacks,
      validation_data=__DS_TEST,
  )
  # delete model
  del model
  # get best history
  best_idx = max(range(len(ret.history['val_accuracy'])), key=ret.history['val_accuracy'].__getitem__)
  best_history = {
      k: v[best_idx] for k, v in ret.history.items()
  }
  if verbose > 0:
    print(f'Best test accuracy: {best_history["val_accuracy"]}')
  return (best_history['val_accuracy'], best_history['accuracy'], n_params)

# %%
#@title Use this form to train specific genomes
#@markdown Enter your genome in this text field and then run this cell.
#@markdown 
__fr_model_genome = "NC 256 5 tanh;RC 64 5 relu;NC 256 5 tanh;NC 4 3 tanh;RC 16 3 tanh;FL relu;" #@param {type:"string"}

#@markdown You can finetune training hyperparameters here, (given values are good defaults and you shouldn't have to change for good results)
__fr_lr = 1e-3 #@param {type:"number"}
__fr_lr_decay = 0.1 #@param {type:"number"}

try:
  # Train
  print('Return value:', train_model(__fr_model_genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay))
except Exception as e:
  print(e)
  print()
  print(f'Your input genome: {__fr_model_genome}')
# Out:
# Training genome: NC 256 5 tanh;RC 64 5 relu;NC 256 5 tanh;NC 4 3 tanh;RC 16 3 tanh;FL relu;
# Model params: 837726
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 256)       6656
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 64)        409664
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 256)       409856
#
#  Layer_3_NC (Conv2D)         (None, 12, 12, 4)         9220
#
#  Layer_4_RC (Conv2D)         (None, 5, 5, 16)          592
#
#  global_average_pooling2d_1   (None, 16)               0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 64)                1088
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 837,726
# Trainable params: 837,726
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0239s vs `on_train_batch_end` time: 0.0297s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0239s vs `on_train_batch_end` time: 0.0297s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.4731000065803528
# Return value: (0.4731000065803528, 0.48321667313575745, 837726)

# %%
#@title Deep model genome example
#@markdown Enter your genome in this text field and then run this cell.
#@markdown 
__fr_model_genome = "NC 32 5 relu;RC 32 5 relu;RC 64 6 relu;NC 64 5 relu;NC 16 4 relu;FL relu;" #@param {type:"string"}

#@markdown You can finetune training hyperparameters here, (given values are good defaults and you shouldn't have to change for good results)
__fr_lr = 1e-3 #@param {type:"number"}
__fr_lr_decay = 0.1 #@param {type:"number"}

try:
  # Train
  print('Return value:', train_model(__fr_model_genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay))
except Exception as e:
  print(e)
  print()
  print(f'Your input genome: {__fr_model_genome}')
# Out:
# Training genome: NC 32 5 relu;RC 32 5 relu;RC 64 6 relu;NC 64 5 relu;NC 16 4 relu;FL relu;
# Model params: 220858
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 32)        832
#
#  Layer_1_RC (Conv2D)         (None, 12, 12, 32)        25632
#
#  Layer_2_RC (Conv2D)         (None, 4, 4, 64)          73792
#
#  Layer_3_NC (Conv2D)         (None, 4, 4, 64)          102464
#
#  Layer_4_NC (Conv2D)         (None, 4, 4, 16)          16400
#
#  global_average_pooling2d_2   (None, 16)               0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 64)                1088
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 220,858
# Trainable params: 220,858
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.8995000123977661
# Return value: (0.8995000123977661, 0.916450023651123, 220858)

# %% [markdown]
# ## Hints
#
# - Consider caching genome results for faster querying.
#   - This has a risk. The training process itself is non-deterministic and thus training the same genome multiple times can sometimes give drastically different results. Generally such difference in accuracy of the same genome is small but sometimes it be upto 30%.
# - Consider saving your search algorithm state such that it can resume from a previous search point if it gets interrupted due to a crash or colab time restrictions.
#   - Google colab is free and hence it has time limits on how long you can use the GPU. If you implement checkpointing in your code such that it saves checkpoints on your GDrive, you can save a lot of time when such interruptions happen.
#   - You can mount your GDrive to colab and save/load files from your drive folders.
# - Don't forget to enable GPU in colab.
#   - https://colab.research.google.com/notebooks/gpu.ipynb
# - If colab shows errors in code that was working before try to do `Runtime->Restart Runtime`. This is especially true if you stopped execution while a model was being trained.
#   - You can also try `Runtime->Factory Reset Runtime` to get a clean slate (revert installed libraries to colab defaults).

# %% [markdown]
# # Answer
# Write your answer and its code under this section.

# %% [markdown]
# # NAS search using Evolution Algorithm

# %%
# importing library
import random
# defining the function that generate a random layer from defined filters, functions and kernels
def random_layer(f,l,k,af,layertype):
  while True:
    a = random.randint(0,len(f)-1)
    b = random.randint(0,len(l)-1)
    c = random.randint(0,len(k)-1)
    d = random.randint(0,len(af)-1)
    string = f[a]+" "+l[b]+" "+k[c]+" "+af[d]+";"
    #print(string,string[:2])
    if string[:2]==layertype:
      return string

# defining the function that  generate a random architecture with given number of layers
def random_architecture(k):
  s = []
  a = ''
  for i in range(k-2-1):
    s.append(random_layer(function,filters,kernels,af,"NC"))
  for i in range(2):
    s.append(random_layer(function,filters,kernels,af,"RC"))
  random.shuffle(s)
  s.append("FL relu;")
  for i in range(len(s)):
    a = a + s[i]
  return a


#arch = random_architecture(6)
#print(arch)

# %%
# mutation class containg four different types of mutations.
class Mutation():

  def swap_mutation(self,model_genome):
    """
    Randomly choose two layers in the model genome and swap them
    """
    # creating list and its copies
    la = []
    la = model_genome.split(';')
    fl = "FL relu"
    la.remove("FL relu")
    la_copy = la[:]  
    # print(f"{la}\n{la_copy}")

    # choosing two indices at random
    choice1 = random.choice(la_copy)
    ### print(choice1)
    la_copy.remove(choice1)
    choice2 = random.choice(la_copy)

    index1, index2 = la.index(choice1), la.index(choice2)
    # swapping two layers in the genome
    la[index1], la[index2] = choice2, choice1  
    print(f"Swapping :\n{choice1}\n{choice2}")
    # print(la)
    
    swapped_genome = ";".join(la) + fl + ";"
    # print(swapped_genome)

    return swapped_genome

  def inversion_mutation(self,model_genome):
    """
    Select a sequence of layers at random and invert them
    """
    la = []
    la = model_genome.split(';')
    fl = "FL relu"
    la.remove("FL relu")
    # main_str = ";".join(la)

    idx1 = random.randint(0, len(la)-2)
    idx2 = random.randint(idx1+1, len(la)-1)
    # substr = get_substring(main_str, substr_len)
    sa = la[idx1:idx2]
    print(f"{la}\n{fl}\n{idx1}\n{idx2}\n{sa}")
    
    sa = sa[::-1]
    la[idx1:idx2] = sa

    inverted_genome = ";".join(la) + fl + ";"

    return inverted_genome

  def add_layer_mutation(self,model_genome):
    """
    choose a layers in the model genome and replace them by new layer
    """
    layer1 = []
    layer2 = random_layer(function,filters,kernels,af,"NC")
    layer2 = layer2.split(";")
    print(layer2)
    layer1 = model_genome.split(';') 
    genome = ''
    for i in range(len(layer1)-3):
      if layer1[i][:2] == "NC":
        layer1[i]=layer2[0]
        break
    for i in range(len(layer1)-1):
      genome+=layer1[i]+";"
    print(layer1)
    print(layer2)
    print(genome)
    return genome 
  
  def filter_mutation(self,model_genome):
    """
    Choose a layer in the model genome and change the number of filters in them
    """
    layer1 = model_genome.split(';')
    layer3 = []
    genome = ''
    for i in range(len(layer1)):
      if layer1[i][:2]=="NC":
        s = ''
        b = random.randint(0,len(filters)-1)
        layer2 = layer1[i].split(" ")
        if layer2[1]==filters[b]:
          b = random.randint(0,len(filters)-1)
        layer2[1]=filters[b]
        print(layer2[1])
        for j in range(len(layer2)):
          if j != len(layer2)-1:
            s = s + layer2[j]+" "
          else:
            s = s + layer2[j]
        print(s)
        layer3.append(s)
      else:
        layer3.append(layer1[i])
    for i in range(len(layer3)-1):
      genome+=layer3[i]+";"
    print(layer3)
    return genome

# %%
# defining the class of algorithm
class Evolutionary_algorithm():
  # defining the initial parameters 
  def __init__(self,p,layers):
    self.p = p
    self.layers = layers
    self.population = []
    self.history = []
    self.accuracy = []

  # initialize population
  def initialise(self):
    for i in range(self.p):
      x = random_architecture(self.layers)
      if x not in self.population:
        r = train_model(x, verbose=2, lr=1e-3, lr_decay=0.1)
        self.population.append(x)
        self.history.append(x)
        self.accuracy.append(r)
    return self.population,self.accuracy,self.history

  def search(self, nsamples,mutation:str = 'addl'):
    # running initial algorithm
    while True:
      samples = []
      for i in range(nsamples):
        a = random.randint(0,len(self.population)-1)
        if self.population[a] not in samples:
          samples.append([self.population[a],self.accuracy[a]])
      max1,max2 = 0,0
      j,k = 0,0
      for i in range(len(samples)):
        if samples[i][1][0]>max1:
          max2 = max1
          max1 = samples[i][1][0]
          k = j
          j = i
      print("Architecture having Highest accuracy in samples:\n",samples[j])
      print("Architecture having Second highest accuracy in samples:\n",samples[k])
      if max1>0.75:
        return samples[j],self.population,self.accuracy,self.history
      
      # mutating the genome
      m = Mutation()
      if mutation == 'filter':
        new_ge = m.filter_mutation(samples[j][0])
      elif mutation == 'swap':
        new_ge = m.swap_mutation(samples[j][0])
      elif mutation == 'inversion':
        new_ge = m.inversion_mutation(samples[j][0])
      elif mutation == 'addl':
        new_ge = m.add_layer_mutation(samples[j][0])
      print(new_ge)

      # training model on the mutated genome
      if new_ge not in self.population and mutation != 'swap':
        r = train_model(new_ge, verbose=2, lr=1e-3, lr_decay=0.1)
        if r[0]-samples[j][1][0]>0:
          print("Mutation accuracy is greater than parent adding child to population")
          self.population.append(new_ge)
          self.history.append(new_ge)
          self.accuracy.append(r)
        elif new_ge not in self.population and mutation != 'swap':
          try:
            r = train_model(new_ge, verbose=2, lr=1e-3, lr_decay=0.1)
          except Exception as e:
            continue
          if r[0]-samples[j][1][0]>0:
            print("Mutation accuracy is greater than parent adding child to population")
            self.population.append(new_ge)
            self.history.append(new_ge)
            self.accuracy.append(r)
        else:
          print("Mutation accuracy is less than parent not adding child to population")
      # removing the oldest architecture in population
      if len(self.population)>15:
        print("Maximum population size reached removing oldest architecture")
        self.population.remove(self.population[0])
        self.accuracy.remove(self.accuracy[0])
      else:
        print("Maximum population size not reached.")

  # Defining the function to return best architecture
  def best_architecture(self):
    m = 0
    j = 0
    for i in range(len(self.accuracy)):
      if self.accuracy[i][0]>m:
        m = self.accuracy[i][0]
        j = i
    return self.population[j]

# %%
# creating a search space
function = ["NC","RC"]
# filter are in power of 2 
filters = ["1","2","4","8","16","32","64","128","256"]
# kernels are from 1 to 7
kernels = ["1","2","3","4","5","6","7"]
# activation functions
af = ["relu","sigmoid","tanh"]

# %%
# creating the model object and passing parameters
population_size = 10
number_of_layers = 5 
model = Evolutionary_algorithm(population_size,number_of_layers)
pop , acc, hist = model.initialise()
print(pop)
print(acc)
# Out:
# Training genome: RC 32 1 tanh;NC 1 7 tanh;NC 8 3 tanh;RC 1 3 tanh;FL relu;
# Model params: 2564
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 14, 14, 32)        64
#
#  Layer_1_NC (Conv2D)         (None, 14, 14, 1)         1569
#
#  Layer_2_NC (Conv2D)         (None, 14, 14, 8)         80
#
#  Layer_3_RC (Conv2D)         (None, 6, 6, 1)           73
#
#  global_average_pooling2d_14  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_28 (Dense)            (None, 64)                128
#
#  dense_29 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 2,564
# Trainable params: 2,564
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.3873000144958496
# Training genome: NC 128 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# Model params: 17933
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 128)       256
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 2)         6402
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 128)       4224
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 1)           6273
#
#  global_average_pooling2d_15  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_30 (Dense)            (None, 64)                128
#
#  dense_31 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 17,933
# Trainable params: 17,933
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.5152999758720398
# Training genome: RC 1 2 tanh;NC 4 7 sigmoid;NC 128 3 tanh;RC 128 1 relu;FL relu;
# Model params: 30359
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 14, 14, 1)         5
#
#  Layer_1_NC (Conv2D)         (None, 14, 14, 4)         200
#
#  Layer_2_NC (Conv2D)         (None, 14, 14, 128)       4736
#
#  Layer_3_RC (Conv2D)         (None, 7, 7, 128)         16512
#
#  global_average_pooling2d_16  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_32 (Dense)            (None, 64)                8256
#
#  dense_33 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 30,359
# Trainable params: 30,359
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0071s vs `on_train_batch_end` time: 0.0105s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0071s vs `on_train_batch_end` time: 0.0105s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Training genome: NC 1 5 relu;RC 2 3 tanh;NC 64 4 relu;RC 32 7 tanh;FL relu;
# Model params: 105304
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 1)         26
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 2)         20
#
#  Layer_2_NC (Conv2D)         (None, 13, 13, 64)        2112
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 32)          100384
#
#  global_average_pooling2d_17  (None, 32)               0
#   (GlobalAveragePooling2D)
#
#  dense_34 (Dense)            (None, 64)                2112
#
#  dense_35 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 105,304
# Trainable params: 105,304
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Epoch 00010: early stopping
# Best test accuracy: 0.7501000165939331
# Training genome: RC 2 6 sigmoid;NC 32 2 tanh;NC 16 1 sigmoid;RC 128 4 tanh;FL relu;
# Model params: 42692
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 12, 12, 2)         74
#
#  Layer_1_NC (Conv2D)         (None, 12, 12, 32)        288
#
#  Layer_2_NC (Conv2D)         (None, 12, 12, 16)        528
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 128)         32896
#
#  global_average_pooling2d_18  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_36 (Dense)            (None, 64)                8256
#
#  dense_37 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 42,692
# Trainable params: 42,692
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Training genome: NC 4 3 sigmoid;RC 4 4 relu;RC 2 4 sigmoid;NC 64 4 sigmoid;FL relu;
# Model params: 7352
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 4)         40
#
#  Layer_1_RC (Conv2D)         (None, 13, 13, 4)         260
#
#  Layer_2_RC (Conv2D)         (None, 5, 5, 2)           130
#
#  Layer_3_NC (Conv2D)         (None, 5, 5, 64)          2112
#
#  global_average_pooling2d_19  (None, 64)               0
#   (GlobalAveragePooling2D)
#
#  dense_38 (Dense)            (None, 64)                4160
#
#  dense_39 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 7,352
# Trainable params: 7,352
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Training genome: NC 4 1 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;
# Model params: 19498
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 4)         8
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 16)        80
#
#  Layer_2_RC (Conv2D)         (None, 11, 11, 8)         6280
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 128)         4224
#
#  global_average_pooling2d_20  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_40 (Dense)            (None, 64)                8256
#
#  dense_41 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 19,498
# Trainable params: 19,498
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.5695000290870667
# Training genome: NC 64 1 sigmoid;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;
# Model params: 265547
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 64)        128
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 128)       131200
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 64)        131136
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 1)           2305
#
#  global_average_pooling2d_21  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_42 (Dense)            (None, 64)                128
#
#  dense_43 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 265,547
# Trainable params: 265,547
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0172s vs `on_train_batch_end` time: 0.0281s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0172s vs `on_train_batch_end` time: 0.0281s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Training genome: RC 64 3 tanh;RC 4 5 tanh;NC 8 7 tanh;NC 64 5 relu;FL relu;
# Model params: 26294
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 13, 13, 64)        640
#
#  Layer_1_RC (Conv2D)         (None, 5, 5, 4)           6404
#
#  Layer_2_NC (Conv2D)         (None, 5, 5, 8)           1576
#
#  Layer_3_NC (Conv2D)         (None, 5, 5, 64)          12864
#
#  global_average_pooling2d_22  (None, 64)               0
#   (GlobalAveragePooling2D)
#
#  dense_44 (Dense)            (None, 64)                4160
#
#  dense_45 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 26,294
# Trainable params: 26,294
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.7786999940872192
# Training genome: RC 1 6 tanh;NC 256 7 sigmoid;RC 256 3 relu;NC 8 3 relu;FL relu;
# Model params: 622583
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 12, 12, 1)         37
#
#  Layer_1_NC (Conv2D)         (None, 12, 12, 256)       12800
#
#  Layer_2_RC (Conv2D)         (None, 5, 5, 256)         590080
#
#  Layer_3_NC (Conv2D)         (None, 5, 5, 8)           18440
#
#  global_average_pooling2d_23  (None, 8)                0
#   (GlobalAveragePooling2D)
#
#  dense_46 (Dense)            (None, 64)                576
#
#  dense_47 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 622,583
# Trainable params: 622,583
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0102s vs `on_train_batch_end` time: 0.0124s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0102s vs `on_train_batch_end` time: 0.0124s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# ['RC 32 1 tanh;NC 1 7 tanh;NC 8 3 tanh;RC 1 3 tanh;FL relu;', 'NC 128 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;', 'RC 1 2 tanh;NC 4 7 sigmoid;NC 128 3 tanh;RC 128 1 relu;FL relu;', 'NC 1 5 relu;RC 2 3 tanh;NC 64 4 relu;RC 32 7 tanh;FL relu;', 'RC 2 6 sigmoid;NC 32 2 tanh;NC 16 1 sigmoid;RC 128 4 tanh;FL relu;', 'NC 4 3 sigmoid;RC 4 4 relu;RC 2 4 sigmoid;NC 64 4 sigmoid;FL relu;', 'NC 4 1 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;', 'NC 64 1 sigmoid;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;', 'RC 64 3 tanh;RC 4 5 tanh;NC 8 7 tanh;NC 64 5 relu;FL relu;', 'RC 1 6 tanh;NC 256 7 sigmoid;RC 256 3 relu;NC 8 3 relu;FL relu;']
# [(0.3873000144958496, 0.3795500099658966, 2564), (0.5152999758720398, 0.49648332595825195, 17933), (0.10000000149011612, 0.09974999725818634, 30359), (0.7501000165939331, 0.7588833570480347, 105304), (0.10000000149011612, 0.09989999979734421, 42692), (0.10000000149011612, 0.0997999981045723, 7352), (0.5695000290870667, 0.5699499845504761, 19498), (0.10000000149011612, 0.09988333284854889, 265547), (0.7786999940872192, 0.7819666862487793, 26294), (0.10000000149011612, 0.09763333201408386, 622583)]

# %%
# searching for model
s , pop , acc, hist = model.search(3,'addl')
# Out:
# Architecture having Highest accuracy in samples:
#  ['NC 128 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;', (0.5152999758720398, 0.49648332595825195, 17933)]
# Architecture having Second highest accuracy in samples:
#  ['NC 4 3 sigmoid;RC 4 4 relu;RC 2 4 sigmoid;NC 64 4 sigmoid;FL relu;', (0.10000000149011612, 0.0997999981045723, 7352)]
# ['NC 256 4 tanh', '']
# ['NC 256 4 tanh', 'NC 2 5 relu', 'RC 128 4 tanh', 'RC 1 7 sigmoid', 'FL relu', '']
# ['NC 256 4 tanh', '']
# NC 256 4 tanh;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# NC 256 4 tanh;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# Training genome: NC 256 4 tanh;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# Model params: 28429
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 256)       4352
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 2)         12802
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 128)       4224
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 1)           6273
#
#  global_average_pooling2d_24  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_48 (Dense)            (None, 64)                128
#
#  dense_49 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 28,429
# Trainable params: 28,429
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.45419999957084656
# Training genome: NC 256 4 tanh;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# Model params: 28429
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 256)       4352
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 2)         12802
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 128)       4224
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 1)           6273
#
#  global_average_pooling2d_25  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_50 (Dense)            (None, 64)                128
#
#  dense_51 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 28,429
# Trainable params: 28,429
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Maximum population size not reached.
# Architecture having Highest accuracy in samples:
#  ['NC 4 1 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;', (0.5695000290870667, 0.5699499845504761, 19498)]
# Architecture having Second highest accuracy in samples:
#  ['NC 4 1 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;', (0.5695000290870667, 0.5699499845504761, 19498)]
# ['NC 32 7 sigmoid', '']
# ['NC 32 7 sigmoid', 'NC 16 1 relu', 'RC 8 7 tanh', 'RC 128 2 relu', 'FL relu', '']
# ['NC 32 7 sigmoid', '']
# NC 32 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;
# NC 32 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;
# Training genome: NC 32 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;
# Model params: 21538
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 32)        1600
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 16)        528
#
#  Layer_2_RC (Conv2D)         (None, 11, 11, 8)         6280
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 128)         4224
#
#  global_average_pooling2d_26  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_52 (Dense)            (None, 64)                8256
#
#  dense_53 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 21,538
# Trainable params: 21,538
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.5746999979019165
# Mutation accuracy is greater than parent adding child to population
# Maximum population size not reached.
# Architecture having Highest accuracy in samples:
#  ['NC 64 1 sigmoid;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;', (0.10000000149011612, 0.09988333284854889, 265547)]
# Architecture having Second highest accuracy in samples:
#  ['NC 64 1 sigmoid;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;', (0.10000000149011612, 0.09988333284854889, 265547)]
# ['NC 16 5 tanh', '']
# ['NC 16 5 tanh', 'NC 128 4 sigmoid', 'RC 64 4 relu', 'RC 1 6 sigmoid', 'FL relu', '']
# ['NC 16 5 tanh', '']
# NC 16 5 tanh;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;
# NC 16 5 tanh;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;
# Training genome: NC 16 5 tanh;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;
# Model params: 167531
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 16)        416
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 128)       32896
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 64)        131136
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 1)           2305
#
#  global_average_pooling2d_27  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_54 (Dense)            (None, 64)                128
#
#  dense_55 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 167,531
# Trainable params: 167,531
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0132s vs `on_train_batch_end` time: 0.0199s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0132s vs `on_train_batch_end` time: 0.0199s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Training genome: NC 16 5 tanh;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;
# Model params: 167531
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 16)        416
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 128)       32896
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 64)        131136
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 1)           2305
#
#  global_average_pooling2d_28  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_56 (Dense)            (None, 64)                128
#
#  dense_57 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 167,531
# Trainable params: 167,531
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0135s vs `on_train_batch_end` time: 0.0245s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0135s vs `on_train_batch_end` time: 0.0245s). Check your callbacks.
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# Maximum population size not reached.
# Architecture having Highest accuracy in samples:
#  ['NC 128 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;', (0.5152999758720398, 0.49648332595825195, 17933)]
# Architecture having Second highest accuracy in samples:
#  ['RC 32 1 tanh;NC 1 7 tanh;NC 8 3 tanh;RC 1 3 tanh;FL relu;', (0.3873000144958496, 0.3795500099658966, 2564)]
# ['NC 8 1 relu', '']
# ['NC 8 1 relu', 'NC 2 5 relu', 'RC 128 4 tanh', 'RC 1 7 sigmoid', 'FL relu', '']
# ['NC 8 1 relu', '']
# NC 8 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# NC 8 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# Training genome: NC 8 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# Model params: 11693
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 8)         16
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 2)         402
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 128)       4224
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 1)           6273
#
#  global_average_pooling2d_29  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_58 (Dense)            (None, 64)                128
#
#  dense_59 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 11,693
# Trainable params: 11,693
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.39309999346733093
# Training genome: NC 8 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# Model params: 11693
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 8)         16
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 2)         402
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 128)       4224
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 1)           6273
#
#  global_average_pooling2d_30  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_60 (Dense)            (None, 64)                128
#
#  dense_61 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 11,693
# Trainable params: 11,693
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.3774999976158142
# Maximum population size not reached.
# Architecture having Highest accuracy in samples:
#  ['RC 1 6 tanh;NC 256 7 sigmoid;RC 256 3 relu;NC 8 3 relu;FL relu;', (0.10000000149011612, 0.09763333201408386, 622583)]
# Architecture having Second highest accuracy in samples:
#  ['RC 1 6 tanh;NC 256 7 sigmoid;RC 256 3 relu;NC 8 3 relu;FL relu;', (0.10000000149011612, 0.09763333201408386, 622583)]
# ['NC 1 2 relu', '']
# ['RC 1 6 tanh', 'NC 1 2 relu', 'RC 256 3 relu', 'NC 8 3 relu', 'FL relu', '']
# ['NC 1 2 relu', '']
# RC 1 6 tanh;NC 1 2 relu;RC 256 3 relu;NC 8 3 relu;FL relu;
# RC 1 6 tanh;NC 1 2 relu;RC 256 3 relu;NC 8 3 relu;FL relu;
# Training genome: RC 1 6 tanh;NC 1 2 relu;RC 256 3 relu;NC 8 3 relu;FL relu;
# Model params: 22268
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_RC (Conv2D)         (None, 12, 12, 1)         37
#
#  Layer_1_NC (Conv2D)         (None, 12, 12, 1)         5
#
#  Layer_2_RC (Conv2D)         (None, 5, 5, 256)         2560
#
#  Layer_3_NC (Conv2D)         (None, 5, 5, 8)           18440
#
#  global_average_pooling2d_31  (None, 8)                0
#   (GlobalAveragePooling2D)
#
#  dense_62 (Dense)            (None, 64)                576
#
#  dense_63 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 22,268
# Trainable params: 22,268
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.44909998774528503
# Mutation accuracy is greater than parent adding child to population
# Maximum population size not reached.
# Architecture having Highest accuracy in samples:
#  ['NC 128 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;', (0.5152999758720398, 0.49648332595825195, 17933)]
# Architecture having Second highest accuracy in samples:
#  ['NC 64 1 sigmoid;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;', (0.10000000149011612, 0.09988333284854889, 265547)]
# ['NC 1 5 tanh', '']
# ['NC 1 5 tanh', 'NC 2 5 relu', 'RC 128 4 tanh', 'RC 1 7 sigmoid', 'FL relu', '']
# ['NC 1 5 tanh', '']
# NC 1 5 tanh;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# NC 1 5 tanh;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# Training genome: NC 1 5 tanh;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# Model params: 11353
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 1)         26
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 2)         52
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 128)       4224
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 1)           6273
#
#  global_average_pooling2d_32  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_64 (Dense)            (None, 64)                128
#
#  dense_65 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 11,353
# Trainable params: 11,353
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.3682999908924103
# Training genome: NC 1 5 tanh;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;
# Model params: 11353
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 1)         26
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 2)         52
#
#  Layer_2_RC (Conv2D)         (None, 13, 13, 128)       4224
#
#  Layer_3_RC (Conv2D)         (None, 4, 4, 1)           6273
#
#  global_average_pooling2d_33  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_66 (Dense)            (None, 64)                128
#
#  dense_67 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 11,353
# Trainable params: 11,353
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.3034999966621399
# Maximum population size not reached.
# Architecture having Highest accuracy in samples:
#  ['NC 32 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;', (0.5746999979019165, 0.5845333337783813, 21538)]
# Architecture having Second highest accuracy in samples:
#  ['NC 32 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;', (0.5746999979019165, 0.5845333337783813, 21538)]
# ['NC 64 7 sigmoid', '']
# ['NC 64 7 sigmoid', 'NC 16 1 relu', 'RC 8 7 tanh', 'RC 128 2 relu', 'FL relu', '']
# ['NC 64 7 sigmoid', '']
# NC 64 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;
# NC 64 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;
# Training genome: NC 64 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;
# Model params: 23650
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 64)        3200
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 16)        1040
#
#  Layer_2_RC (Conv2D)         (None, 11, 11, 8)         6280
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 128)         4224
#
#  global_average_pooling2d_34  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_68 (Dense)            (None, 64)                8256
#
#  dense_69 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 23,650
# Trainable params: 23,650
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.5728999972343445
# Training genome: NC 64 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;
# Model params: 23650
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 64)        3200
#
#  Layer_1_NC (Conv2D)         (None, 28, 28, 16)        1040
#
#  Layer_2_RC (Conv2D)         (None, 11, 11, 8)         6280
#
#  Layer_3_RC (Conv2D)         (None, 5, 5, 128)         4224
#
#  global_average_pooling2d_35  (None, 128)              0
#   (GlobalAveragePooling2D)
#
#  dense_70 (Dense)            (None, 64)                8256
#
#  dense_71 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 23,650
# Trainable params: 23,650
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 4/10
# 0/469           ETA: ?s -
# Epoch 5/10
# 0/469           ETA: ?s -
# Epoch 6/10
# 0/469           ETA: ?s -
# Epoch 7/10
# 0/469           ETA: ?s -
# Epoch 8/10
# 0/469           ETA: ?s -
# Epoch 9/10
# 0/469           ETA: ?s -
# Epoch 10/10
# 0/469           ETA: ?s -
# Best test accuracy: 0.4593999981880188
# Maximum population size not reached.
# Architecture having Highest accuracy in samples:
#  ['RC 64 3 tanh;RC 4 5 tanh;NC 8 7 tanh;NC 64 5 relu;FL relu;', (0.7786999940872192, 0.7819666862487793, 26294)]
# Architecture having Second highest accuracy in samples:
#  ['RC 64 3 tanh;RC 4 5 tanh;NC 8 7 tanh;NC 64 5 relu;FL relu;', (0.7786999940872192, 0.7819666862487793, 26294)]

# %%
best_arch = model.best_architecture()
print("Best architecture is:\n",best_arch)
print("Architecture Returned by search:\n",s)
print("Architecture in Population are:\n",pop)
print("Accuracy in Population are:\n",acc)
print("Architecture history is:\n",hist)
# Out:
# Best architecture is:
#  RC 64 3 tanh;RC 4 5 tanh;NC 8 7 tanh;NC 64 5 relu;FL relu;
# Architecture Returned by search:
#  ['RC 64 3 tanh;RC 4 5 tanh;NC 8 7 tanh;NC 64 5 relu;FL relu;', (0.7786999940872192, 0.7819666862487793, 26294)]
# Architecture in Population are:
#  ['RC 32 1 tanh;NC 1 7 tanh;NC 8 3 tanh;RC 1 3 tanh;FL relu;', 'NC 128 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;', 'RC 1 2 tanh;NC 4 7 sigmoid;NC 128 3 tanh;RC 128 1 relu;FL relu;', 'NC 1 5 relu;RC 2 3 tanh;NC 64 4 relu;RC 32 7 tanh;FL relu;', 'RC 2 6 sigmoid;NC 32 2 tanh;NC 16 1 sigmoid;RC 128 4 tanh;FL relu;', 'NC 4 3 sigmoid;RC 4 4 relu;RC 2 4 sigmoid;NC 64 4 sigmoid;FL relu;', 'NC 4 1 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;', 'NC 64 1 sigmoid;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;', 'RC 64 3 tanh;RC 4 5 tanh;NC 8 7 tanh;NC 64 5 relu;FL relu;', 'RC 1 6 tanh;NC 256 7 sigmoid;RC 256 3 relu;NC 8 3 relu;FL relu;', 'NC 32 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;', 'RC 1 6 tanh;NC 1 2 relu;RC 256 3 relu;NC 8 3 relu;FL relu;']
# Accuracy in Population are:
#  [(0.3873000144958496, 0.3795500099658966, 2564), (0.5152999758720398, 0.49648332595825195, 17933), (0.10000000149011612, 0.09974999725818634, 30359), (0.7501000165939331, 0.7588833570480347, 105304), (0.10000000149011612, 0.09989999979734421, 42692), (0.10000000149011612, 0.0997999981045723, 7352), (0.5695000290870667, 0.5699499845504761, 19498), (0.10000000149011612, 0.09988333284854889, 265547), (0.7786999940872192, 0.7819666862487793, 26294), (0.10000000149011612, 0.09763333201408386, 622583), (0.5746999979019165, 0.5845333337783813, 21538), (0.44909998774528503, 0.4535500109195709, 22268)]
# Architecture history is:
#  ['RC 32 1 tanh;NC 1 7 tanh;NC 8 3 tanh;RC 1 3 tanh;FL relu;', 'NC 128 1 relu;NC 2 5 relu;RC 128 4 tanh;RC 1 7 sigmoid;FL relu;', 'RC 1 2 tanh;NC 4 7 sigmoid;NC 128 3 tanh;RC 128 1 relu;FL relu;', 'NC 1 5 relu;RC 2 3 tanh;NC 64 4 relu;RC 32 7 tanh;FL relu;', 'RC 2 6 sigmoid;NC 32 2 tanh;NC 16 1 sigmoid;RC 128 4 tanh;FL relu;', 'NC 4 3 sigmoid;RC 4 4 relu;RC 2 4 sigmoid;NC 64 4 sigmoid;FL relu;', 'NC 4 1 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;', 'NC 64 1 sigmoid;NC 128 4 sigmoid;RC 64 4 relu;RC 1 6 sigmoid;FL relu;', 'RC 64 3 tanh;RC 4 5 tanh;NC 8 7 tanh;NC 64 5 relu;FL relu;', 'RC 1 6 tanh;NC 256 7 sigmoid;RC 256 3 relu;NC 8 3 relu;FL relu;', 'NC 32 7 sigmoid;NC 16 1 relu;RC 8 7 tanh;RC 128 2 relu;FL relu;', 'RC 1 6 tanh;NC 1 2 relu;RC 256 3 relu;NC 8 3 relu;FL relu;']

# %% [markdown]
# # NAS Using Random Algorithm

# %%
def Search_space():
  nc_layers = []
  rc_layers =[]
  for i in range(len(function)):
    for j in range(len(filters)):
      for k in range(len(kernels)):
        for l in range(len(af)):
          str = function[i]+" "+filters[j]+" "+kernels[k]+" "+af[l]
          if function[i]=='NC':
            nc_layers.append(str)
          else:
            rc_layers.append(str)
  print(nc_layers) 
  print(rc_layers)
  return nc_layers,rc_layers

# %%
from random import randint
nc , rc = Search_space()
a = []
states = []
genome = nc[0]+";"+rc[0]+";"+rc[1]+";"+"FL relu;"
r= train_model(genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay)
print(r)
a.append([genome,r[0]*100])
t = 10
while r[0]*100<75 and t>0 :
  a = randint(0,len(nc)-1)
  b = randint(0,len(rc)-1)
  c = randint(0,len(rc)-1)
  if r[0]>0.75 and r[0]<0.85:
    genome = nc[a]+";"+rc[b]+";"+rc[c]+";"+"FL relu;"
  r= train_model(genome, verbose=2, lr=__fr_lr, lr_decay=__fr_lr_decay)
  print(r)
  accuracy.append([genome,r[0]*100])
  t = t - 1
# Out:
# ['NC 1 1 relu', 'NC 1 1 sigmoid', 'NC 1 1 tanh', 'NC 1 2 relu', 'NC 1 2 sigmoid', 'NC 1 2 tanh', 'NC 1 3 relu', 'NC 1 3 sigmoid', 'NC 1 3 tanh', 'NC 1 4 relu', 'NC 1 4 sigmoid', 'NC 1 4 tanh', 'NC 1 5 relu', 'NC 1 5 sigmoid', 'NC 1 5 tanh', 'NC 1 6 relu', 'NC 1 6 sigmoid', 'NC 1 6 tanh', 'NC 1 7 relu', 'NC 1 7 sigmoid', 'NC 1 7 tanh', 'NC 2 1 relu', 'NC 2 1 sigmoid', 'NC 2 1 tanh', 'NC 2 2 relu', 'NC 2 2 sigmoid', 'NC 2 2 tanh', 'NC 2 3 relu', 'NC 2 3 sigmoid', 'NC 2 3 tanh', 'NC 2 4 relu', 'NC 2 4 sigmoid', 'NC 2 4 tanh', 'NC 2 5 relu', 'NC 2 5 sigmoid', 'NC 2 5 tanh', 'NC 2 6 relu', 'NC 2 6 sigmoid', 'NC 2 6 tanh', 'NC 2 7 relu', 'NC 2 7 sigmoid', 'NC 2 7 tanh', 'NC 4 1 relu', 'NC 4 1 sigmoid', 'NC 4 1 tanh', 'NC 4 2 relu', 'NC 4 2 sigmoid', 'NC 4 2 tanh', 'NC 4 3 relu', 'NC 4 3 sigmoid', 'NC 4 3 tanh', 'NC 4 4 relu', 'NC 4 4 sigmoid', 'NC 4 4 tanh', 'NC 4 5 relu', 'NC 4 5 sigmoid', 'NC 4 5 tanh', 'NC 4 6 relu', 'NC 4 6 sigmoid', 'NC 4 6 tanh', 'NC 4 7 relu', 'NC 4 7 sigmoid', 'NC 4 7 tanh', 'NC 8 1 relu', 'NC 8 1 sigmoid', 'NC 8 1 tanh', 'NC 8 2 relu', 'NC 8 2 sigmoid', 'NC 8 2 tanh', 'NC 8 3 relu', 'NC 8 3 sigmoid', 'NC 8 3 tanh', 'NC 8 4 relu', 'NC 8 4 sigmoid', 'NC 8 4 tanh', 'NC 8 5 relu', 'NC 8 5 sigmoid', 'NC 8 5 tanh', 'NC 8 6 relu', 'NC 8 6 sigmoid', 'NC 8 6 tanh', 'NC 8 7 relu', 'NC 8 7 sigmoid', 'NC 8 7 tanh', 'NC 16 1 relu', 'NC 16 1 sigmoid', 'NC 16 1 tanh', 'NC 16 2 relu', 'NC 16 2 sigmoid', 'NC 16 2 tanh', 'NC 16 3 relu', 'NC 16 3 sigmoid', 'NC 16 3 tanh', 'NC 16 4 relu', 'NC 16 4 sigmoid', 'NC 16 4 tanh', 'NC 16 5 relu', 'NC 16 5 sigmoid', 'NC 16 5 tanh', 'NC 16 6 relu', 'NC 16 6 sigmoid', 'NC 16 6 tanh', 'NC 16 7 relu', 'NC 16 7 sigmoid', 'NC 16 7 tanh', 'NC 32 1 relu', 'NC 32 1 sigmoid', 'NC 32 1 tanh', 'NC 32 2 relu', 'NC 32 2 sigmoid', 'NC 32 2 tanh', 'NC 32 3 relu', 'NC 32 3 sigmoid', 'NC 32 3 tanh', 'NC 32 4 relu', 'NC 32 4 sigmoid', 'NC 32 4 tanh', 'NC 32 5 relu', 'NC 32 5 sigmoid', 'NC 32 5 tanh', 'NC 32 6 relu', 'NC 32 6 sigmoid', 'NC 32 6 tanh', 'NC 32 7 relu', 'NC 32 7 sigmoid', 'NC 32 7 tanh', 'NC 64 1 relu', 'NC 64 1 sigmoid', 'NC 64 1 tanh', 'NC 64 2 relu', 'NC 64 2 sigmoid', 'NC 64 2 tanh', 'NC 64 3 relu', 'NC 64 3 sigmoid', 'NC 64 3 tanh', 'NC 64 4 relu', 'NC 64 4 sigmoid', 'NC 64 4 tanh', 'NC 64 5 relu', 'NC 64 5 sigmoid', 'NC 64 5 tanh', 'NC 64 6 relu', 'NC 64 6 sigmoid', 'NC 64 6 tanh', 'NC 64 7 relu', 'NC 64 7 sigmoid', 'NC 64 7 tanh', 'NC 128 1 relu', 'NC 128 1 sigmoid', 'NC 128 1 tanh', 'NC 128 2 relu', 'NC 128 2 sigmoid', 'NC 128 2 tanh', 'NC 128 3 relu', 'NC 128 3 sigmoid', 'NC 128 3 tanh', 'NC 128 4 relu', 'NC 128 4 sigmoid', 'NC 128 4 tanh', 'NC 128 5 relu', 'NC 128 5 sigmoid', 'NC 128 5 tanh', 'NC 128 6 relu', 'NC 128 6 sigmoid', 'NC 128 6 tanh', 'NC 128 7 relu', 'NC 128 7 sigmoid', 'NC 128 7 tanh', 'NC 256 1 relu', 'NC 256 1 sigmoid', 'NC 256 1 tanh', 'NC 256 2 relu', 'NC 256 2 sigmoid', 'NC 256 2 tanh', 'NC 256 3 relu', 'NC 256 3 sigmoid', 'NC 256 3 tanh', 'NC 256 4 relu', 'NC 256 4 sigmoid', 'NC 256 4 tanh', 'NC 256 5 relu', 'NC 256 5 sigmoid', 'NC 256 5 tanh', 'NC 256 6 relu', 'NC 256 6 sigmoid', 'NC 256 6 tanh', 'NC 256 7 relu', 'NC 256 7 sigmoid', 'NC 256 7 tanh']
# ['RC 1 1 relu', 'RC 1 1 sigmoid', 'RC 1 1 tanh', 'RC 1 2 relu', 'RC 1 2 sigmoid', 'RC 1 2 tanh', 'RC 1 3 relu', 'RC 1 3 sigmoid', 'RC 1 3 tanh', 'RC 1 4 relu', 'RC 1 4 sigmoid', 'RC 1 4 tanh', 'RC 1 5 relu', 'RC 1 5 sigmoid', 'RC 1 5 tanh', 'RC 1 6 relu', 'RC 1 6 sigmoid', 'RC 1 6 tanh', 'RC 1 7 relu', 'RC 1 7 sigmoid', 'RC 1 7 tanh', 'RC 2 1 relu', 'RC 2 1 sigmoid', 'RC 2 1 tanh', 'RC 2 2 relu', 'RC 2 2 sigmoid', 'RC 2 2 tanh', 'RC 2 3 relu', 'RC 2 3 sigmoid', 'RC 2 3 tanh', 'RC 2 4 relu', 'RC 2 4 sigmoid', 'RC 2 4 tanh', 'RC 2 5 relu', 'RC 2 5 sigmoid', 'RC 2 5 tanh', 'RC 2 6 relu', 'RC 2 6 sigmoid', 'RC 2 6 tanh', 'RC 2 7 relu', 'RC 2 7 sigmoid', 'RC 2 7 tanh', 'RC 4 1 relu', 'RC 4 1 sigmoid', 'RC 4 1 tanh', 'RC 4 2 relu', 'RC 4 2 sigmoid', 'RC 4 2 tanh', 'RC 4 3 relu', 'RC 4 3 sigmoid', 'RC 4 3 tanh', 'RC 4 4 relu', 'RC 4 4 sigmoid', 'RC 4 4 tanh', 'RC 4 5 relu', 'RC 4 5 sigmoid', 'RC 4 5 tanh', 'RC 4 6 relu', 'RC 4 6 sigmoid', 'RC 4 6 tanh', 'RC 4 7 relu', 'RC 4 7 sigmoid', 'RC 4 7 tanh', 'RC 8 1 relu', 'RC 8 1 sigmoid', 'RC 8 1 tanh', 'RC 8 2 relu', 'RC 8 2 sigmoid', 'RC 8 2 tanh', 'RC 8 3 relu', 'RC 8 3 sigmoid', 'RC 8 3 tanh', 'RC 8 4 relu', 'RC 8 4 sigmoid', 'RC 8 4 tanh', 'RC 8 5 relu', 'RC 8 5 sigmoid', 'RC 8 5 tanh', 'RC 8 6 relu', 'RC 8 6 sigmoid', 'RC 8 6 tanh', 'RC 8 7 relu', 'RC 8 7 sigmoid', 'RC 8 7 tanh', 'RC 16 1 relu', 'RC 16 1 sigmoid', 'RC 16 1 tanh', 'RC 16 2 relu', 'RC 16 2 sigmoid', 'RC 16 2 tanh', 'RC 16 3 relu', 'RC 16 3 sigmoid', 'RC 16 3 tanh', 'RC 16 4 relu', 'RC 16 4 sigmoid', 'RC 16 4 tanh', 'RC 16 5 relu', 'RC 16 5 sigmoid', 'RC 16 5 tanh', 'RC 16 6 relu', 'RC 16 6 sigmoid', 'RC 16 6 tanh', 'RC 16 7 relu', 'RC 16 7 sigmoid', 'RC 16 7 tanh', 'RC 32 1 relu', 'RC 32 1 sigmoid', 'RC 32 1 tanh', 'RC 32 2 relu', 'RC 32 2 sigmoid', 'RC 32 2 tanh', 'RC 32 3 relu', 'RC 32 3 sigmoid', 'RC 32 3 tanh', 'RC 32 4 relu', 'RC 32 4 sigmoid', 'RC 32 4 tanh', 'RC 32 5 relu', 'RC 32 5 sigmoid', 'RC 32 5 tanh', 'RC 32 6 relu', 'RC 32 6 sigmoid', 'RC 32 6 tanh', 'RC 32 7 relu', 'RC 32 7 sigmoid', 'RC 32 7 tanh', 'RC 64 1 relu', 'RC 64 1 sigmoid', 'RC 64 1 tanh', 'RC 64 2 relu', 'RC 64 2 sigmoid', 'RC 64 2 tanh', 'RC 64 3 relu', 'RC 64 3 sigmoid', 'RC 64 3 tanh', 'RC 64 4 relu', 'RC 64 4 sigmoid', 'RC 64 4 tanh', 'RC 64 5 relu', 'RC 64 5 sigmoid', 'RC 64 5 tanh', 'RC 64 6 relu', 'RC 64 6 sigmoid', 'RC 64 6 tanh', 'RC 64 7 relu', 'RC 64 7 sigmoid', 'RC 64 7 tanh', 'RC 128 1 relu', 'RC 128 1 sigmoid', 'RC 128 1 tanh', 'RC 128 2 relu', 'RC 128 2 sigmoid', 'RC 128 2 tanh', 'RC 128 3 relu', 'RC 128 3 sigmoid', 'RC 128 3 tanh', 'RC 128 4 relu', 'RC 128 4 sigmoid', 'RC 128 4 tanh', 'RC 128 5 relu', 'RC 128 5 sigmoid', 'RC 128 5 tanh', 'RC 128 6 relu', 'RC 128 6 sigmoid', 'RC 128 6 tanh', 'RC 128 7 relu', 'RC 128 7 sigmoid', 'RC 128 7 tanh', 'RC 256 1 relu', 'RC 256 1 sigmoid', 'RC 256 1 tanh', 'RC 256 2 relu', 'RC 256 2 sigmoid', 'RC 256 2 tanh', 'RC 256 3 relu', 'RC 256 3 sigmoid', 'RC 256 3 tanh', 'RC 256 4 relu', 'RC 256 4 sigmoid', 'RC 256 4 tanh', 'RC 256 5 relu', 'RC 256 5 sigmoid', 'RC 256 5 tanh', 'RC 256 6 relu', 'RC 256 6 sigmoid', 'RC 256 6 tanh', 'RC 256 7 relu', 'RC 256 7 sigmoid', 'RC 256 7 tanh']
# Training genome: NC 1 1 relu;RC 1 1 relu;RC 1 1 sigmoid;FL relu;
# Model params: 784
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_0_NC (Conv2D)         (None, 28, 28, 1)         2
#
#  Layer_1_RC (Conv2D)         (None, 14, 14, 1)         2
#
#  Layer_2_RC (Conv2D)         (None, 7, 7, 1)           2
#
#  global_average_pooling2d_36  (None, 1)                0
#   (GlobalAveragePooling2D)
#
#  dense_72 (Dense)            (None, 64)                128
#
#  dense_73 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 784
# Trainable params: 784
# Non-trainable params: 0
# _________________________________________________________________
# Training:   0%|           0/10 ETA: ?s,  ?epochs/s
# Epoch 1/10
# 0/469           ETA: ?s -
# Epoch 2/10
# 0/469           ETA: ?s -
# Epoch 3/10
# 0/469           ETA: ?s -
# Epoch 00003: early stopping
# Best test accuracy: 0.10000000149011612
# (0.10000000149011612, 0.09943333268165588, 784)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-59056356c174> in <module>()
#      10 t = 10
#      11 while r[0]*100<75 and t>0 :
# ---> 12   a = randint(0,len(nc_layers)-1)
#      13   b = randint(0,len(rc_layers)-1)
#      14   c = randint(0,len(rc_layers)-1)
#
# NameError: name 'nc_layers' is not defined

# %%
for i in range(len(a)):
  print(states[i],a[i])
